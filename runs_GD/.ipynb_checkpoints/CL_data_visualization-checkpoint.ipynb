# %% [markdown]
# ## CN Class and Cocktail mixer

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import h5py
import os

class ChemicalNetwork:

    def __init__(self, num_species, num_input, num_output, n_desc, conc_hidden, conc_out):
        """
        Initialize the Chemical Network

        :param num_species: Number of chemical species in the network
        :n_desc: Number of descendants of K
        :conc_hidden/out: concentration of the species in the hidden/out layers
        """

        self.num_species = num_species
        self.num_input = num_input      # number of input nodes
        self.num_output = num_output    # number of output nodes 

        if (num_input + num_output > num_species):  
             raise ValueError("Input and output layers overlap")

        self.num_desc = n_desc

        self.concentration = np.ones(num_species) # total concentrations
        self.concentration[:num_species-num_output] = conc_hidden # the input concentrations are overwritten when running inference dynamics 
        self.concentration[num_species-num_output:] = conc_out
        self.conc_out = conc_out
        self.conc_hidden = conc_hidden
        self.conc_hidden_min = 0.2
        self.conc_hidden_max = 5
        self.list_conc_out = conc_out*np.ones(n_desc)
        self.list_conc_hidden = conc_hidden*np.ones(n_desc)

        # initialisation of the dynamic variables (affinities)
        self.states = [np.zeros(num_species) for _ in range(n_desc)] # neuronal variables for all descendants

        # interaction matrix 
        self.Ks = [np.zeros((num_species, num_species)) for _ in range(n_desc)]
        self.Ksymm = np.ones((num_species, num_species)) # used to enforce symmetry of Ks 
        for i in range(1,num_species):
            for j in range(0,i):
                self.Ksymm[i,j]=0.0

        # print('Ksymm=',self.Ksymm)
        self.Kmask = np.ones((num_species, num_species))
        for i in range(0,num_species): # used to set self-interactions = 0
            self.Kmask[i,i] = 0.0
        self.Kmask[:num_input,:num_input] = 0.0 # used to switch off the interaction between input species 
        # print('Kmask=',self.Kmask)

        # score ranks the different models 
        self.scores = np.zeros(n_desc) 

    def clone_K(self,mean,sigma): # this routine should be vectorized 
        K=self.Ks[0]
        for i in range(1,self.num_desc):
            normal_matrix = np.random.lognormal(mean=mean, sigma=sigma, size=(self.num_species,self.num_species))
            normal_matrix = normal_matrix*self.Kmask*self.Ksymm
            normal_matrix = normal_matrix+normal_matrix.T
            self.Ks[i] = np.minimum(K*normal_matrix,np.power(10.,4.))  

    def initialise_K(self,mean_0,sigma_0,mean,sigma):
        K= np.random.lognormal(mean=mean_0, sigma=sigma_0, size=(self.num_species,self.num_species))
        K=K*self.Kmask*self.Ksymm
        K=K+K.T
        self.Ks[0]=K
        self.clone_K(mean, sigma)

# vectorized
    def network_dynamics(self, K, Input_concentrations, conc_hidden, conc_out, precision):
        """
        Vectorized network dynamics where all patterns share the same interaction matrix (K).

        :param K: Interaction matrix (shape: [num_species, num_species])
        :param Input_concentrations: Batch of input concentration vectors (shape: [batch_size, num_input])
        :param conc_hidden: Hidden layer concentration
        :param conc_out: Output layer concentration
        :param precision: Tolerance for convergence
        :return: Final states for all input patterns, and the number of iterations per pattern
        """
        batch_size = Input_concentrations.shape[0]  # Number of input patterns
        num_species = self.num_species

        # Initialize concentrations for all input patterns
        concentrations = np.ones((batch_size, num_species)) * conc_hidden
        concentrations[:, :self.num_input] = Input_concentrations  # Set input concentrations
        concentrations[:, -self.num_output:] = conc_out  # Set output concentrations

        # Initialize states and convergence variables
        states = np.zeros((batch_size, num_species))  # Shape: [batch_size, num_species]
        prev_states = np.zeros_like(states)
        ac_precision = 2.0 * precision * np.ones(batch_size)  # One precision value per pattern
        # max_iterations = 1000  # Optional: Set a maximum number of iterations
        iteration_counts = np.zeros(batch_size, dtype=int)  # Track iterations for each pattern

        # Iteratively solve for equilibrium concentrations
        while np.any(ac_precision > precision):  # Continue until all patterns converge
            prev_states = states.copy()
            states = concentrations / (1.0 + np.dot(states, K.T))  # Update states in parallel for all patterns
            deltas = 2.0 * np.abs(prev_states - states) / (np.abs(prev_states + states) + precision / 10)
            ac_precision = np.max(deltas, axis=1)  # Update precision for each pattern
            iteration_counts += 1
#        if np.all(iteration_counts >= max_iterations):  # Safety check to prevent infinite loops
#            break

        return states, iteration_counts


    def compute_losses(self,labels,outputs,loss,out_losses):
        N_patt = labels.shape[0]
        c_inf = np.min(labels)
        c_sup = np.max(labels)

        if loss == 1:  # entropic loss

            s_matrix = (labels - c_inf) / (c_sup - c_inf) 
            outputs_clipped = np.clip(outputs, 1e-10, self.conc_out)
            off_list=np.log(np.max((1-s_matrix)*outputs_clipped,axis=1))
            on_list=np.min(s_matrix*np.log(outputs_clipped),axis=1)
            list_losses=off_list-on_list
            score = np.average(list_losses)

            ## two old versions 
            #indinc = (labels - c_inf) / (c_sup - c_inf)  # Shape: [N_patt, num_output]
            #outputs_clipped = np.clip(outputs, 1e-10, self.conc_out)  # to avoid computing 1./0. and log(0.)  
            #num = np.sum(indic * outputs, axis=1)            
            #den = np.max((1-indic) * outputs, axis=1)
            ##if out_losses == 1:
            #list_losses = -np.log(num/den)    
            #score = np.sum(-np.log(num/den))
            ##
            ## version with preaverage over the patterns belonging to the same class  
            ##
            #label_indices = np.argmax(labels, axis=1) # Shape: [N_patt]; label_indices=0,1,2
            #num_labels=labels.shape[1]
            #score_label=np.zeros(num_labels)
            #for label in range(num_labels):
            #    mask = (label_indices == label)  # Boolean mask for current label    
            #    score_label[label]=np.sum(list_losses[mask])
            #score=np.max(score_label)

        elif loss == 2:  # mean squared error (mse) 

            if out_losses == 1:
                list_losses = np.sum(np.power(outputs - labels, 2),axis=1)
            score = np.average(np.power(outputs - labels, 2))*3./2

        elif loss == 3: # contrast loss

            s_matrix = (labels - c_inf) / (c_sup - c_inf)  # Shape: [N_patt, num_output]
            outputs_clipped = np.clip(outputs, 1e-10, self.conc_out)/self.conc_out  # regularizators  

            #label_indices = np.argmax(labels, axis=1) # Shape: [N_patt]; label_indices=0,1,2
            #num_labels=labels.shape[1]
            on_matrix=s_matrix*np.log(outputs_clipped)            
            off_matrix=(1.-s_matrix)*outputs_clipped

            ## first version of the score 
            # score=-np.average(on_matrix)+0.5*np.average(np.log(np.average(off_matrix,axis=0)))
            list_scores=np.log(3./2.*np.average(off_matrix,axis=0))-3.*np.average(on_matrix,axis=0)
            score=np.max(list_scores)
            
            if out_losses == 1:
                list_losses=np.average(on_matrix,axis=1)

        elif loss == 4: # symmetric loss
            
            s_matrix = (labels - c_inf) / (c_sup - c_inf)  # Shape: [N_patt, num_output]
            outputs_clipped = np.clip(outputs, 1e-10, self.conc_out)/self.conc_out  # regularizators 

            on_matrix=np.log(1-np.min(s_matrix*outputs_clipped,axis=1))
            off_matrix=np.log(np.max((1-s_matrix)*outputs_clipped,axis=1))

            list_losses=on_matrix+off_matrix
            score=np.average(list_losses)


        else:
            raise ValueError("Invalid loss type. Must be 1, or 2, or 3, or 4.")

        if out_losses == 1:

            return score , list_losses
        else:
            return score 

# vectorized 
    def test_models(self, patterns, labels, K, conc_hidden, conc_out, precision, loss, out_losses):
        """
        Test models: We assume a one-hot encoding of the labels which are assumed to be equal to (c_inf, c_inf, ..., c_sup, c_inf, ...)

        :param loss: 
            0 - Cross entropy loss
            1 - Unconventional loss (requires c_inf=0 and c_sup=c_out)
            2 - Mean squared (MS) loss
        :return: Average loss across all patterns
        """
#        N_patt = patterns.shape[0]  # Number of patterns
        i_out = self.num_species - labels.shape[1]  # Output indices
#        c_inf = np.min(labels)
#        c_sup = np.max(labels)

        # Run vectorized network dynamics for all patterns
        states, _ = self.network_dynamics(K, patterns, conc_hidden, conc_out, precision)

        # Extract output states for all patterns
        outputs = states[:, i_out:]  # Shape: [N_patt, num_output]
        
        if out_losses == 1:
            score , list_losses = self.compute_losses(labels,outputs,loss,out_losses)
            return score , list_losses
        else:
            score = self.compute_losses(labels,outputs,loss,out_losses)
            return score 


    def parallel_test_models(self, patterns, labels, conc_hidden, conc_out, precision, loss, out_losses):  # Now fully sequential

        n_des = len(self.Ks)
        n_batch=patterns.shape[0]
        self.scores = []  # Clear the previous scores

        if out_losses == 1:
            tab_losses = np.empty((0,n_batch))

        for i in range(n_des):  # Sequential iteration over all Ks while probing different concentrations
            score_list=np.zeros(3)
            concs_hidden=conc_hidden*np.array([0.97,1.0,1.0/0.97])
            concs_hidden=np.minimum(concs_hidden,self.conc_hidden_max)
            concs_hidden=np.maximum(concs_hidden,self.conc_hidden_min)
            if out_losses == 1:
                score_list[0], losses_0 = self.test_models(patterns, labels, self.Ks[i], concs_hidden[0], conc_out, precision,loss, out_losses)
                score_list[1], losses_1 = self.test_models(patterns, labels, self.Ks[i], concs_hidden[1], conc_out, precision,loss, out_losses)
                score_list[2], losses_2 = self.test_models(patterns, labels, self.Ks[i], concs_hidden[2], conc_out, precision,loss, out_losses)
            else:
                score_list[0] = self.test_models(patterns, labels, self.Ks[i], concs_hidden[0], conc_out, precision,loss, out_losses)
                score_list[1] = self.test_models(patterns, labels, self.Ks[i], concs_hidden[1], conc_out, precision,loss, out_losses)
                score_list[2] = self.test_models(patterns, labels, self.Ks[i], concs_hidden[2], conc_out, precision,loss, out_losses)
            iopt=np.argmin(score_list)
            self.list_conc_hidden[i]=concs_hidden[iopt]
            self.scores.append(score_list[iopt])  # Store the resulting score
            if out_losses == 1:
                if iopt == 0:
                    losses=losses_0
                elif iopt == 1:
                    losses=losses_1
                elif iopt == 2:
                    losses=losses_2
                tab_losses = np.vstack(([tab_losses,losses]))        
        if out_losses == 1:
            return tab_losses


    def update_K(self,mean,sigma):
        iopt=np.argmin(self.scores) # carefull, this argmax will pick up the first index when the scores are comparable
        self.scores[0]=self.scores[iopt]
        self.conc_hidden=self.list_conc_hidden[iopt]
        self.Ks[0]=np.copy(self.Ks[iopt])
        self.clone_K(mean,sigma)
        self.list_conc_hidden=self.conc_hidden*np.ones(self.num_desc)


    # used to print out average and variance versus time of the output activities 
    # vectorized
    def output_activities(self, patterns, labels, conc_hidden, conc_out, precision, loss):
        """
        Compute affinities of the most performant model, assuming a one-hot encoding of labels.

        :param patterns: Array of input patterns (shape: [N_patt, num_input])
        :param labels: Array of one-hot encoded labels (shape: [N_patt, num_output])
        :param conc_hidden: Hidden layer concentration
        :param conc_out: Output layer concentration
        :param precision: Precision for equilibrium calculation
        :return: Normalized activities (shape: [num_labels, num_output])
        """
        N_patt = patterns.shape[0]  # Number of patterns
        i_out = self.num_species - labels.shape[1]  # Output indices
        num_output = self.num_species - i_out       # Number of output species
        num_labels = labels.shape[1]               # Number of unique labels

        # Initialize mean activities, variance of the activities, and counts
        activities = np.zeros((num_labels, num_output))
        variance_activity = np.zeros((num_labels, num_output))
        #counts = np.zeros((num_labels, num_output))

        # Run network dynamics for all patterns in a batch
        states, _ = self.network_dynamics(self.Ks[0], patterns, conc_hidden, conc_out, precision)

        # Extract output states for all patterns
        outputs = states[:, i_out:]  # Shape: [N_patt, num_output]

        # Determine the label indices for each pattern (assuming one-hot encoding)
        label_indices = np.argmax(labels, axis=1)  # Shape: [N_patt]

        # Vectorized aggregation of activities and counts
        for label in range(num_labels):
            mask = (label_indices == label)  # Boolean mask for current label
            activities[label] = np.mean(outputs[mask], axis=0) 
            variance_activity[label] = np.var(outputs[mask], axis=0)
        #    counts[label] = np.sum(mask)  # Count occurrences of this label

# no divisions by zero when using balanced batches (i.e., with the same number of patterns/class)             
#        # Normalize activities by counts
#        with np.errstate(divide='ignore', invalid='ignore'):  # Handle division by zero safely
#            # normalized_activities = np.nan_to_num(activities / counts[:, None])
#            normalized_activities = np.nan_to_num(activities / counts)

        out_losses=0
        ac_score = self.compute_losses(labels,outputs,loss,out_losses)
        
        return ac_score, activities, variance_activity

# vectorized
    def test_model(self, patterns, labels, conc_hidden, conc_out, precision):
        """
        Prepares scatter plot data by computing output states and grouping by label.

        :param patterns: Array of input patterns (shape: [N_patt, num_input])
        :param labels: Array of one-hot encoded labels (shape: [N_patt, num_labels])
        :param conc_hidden: Hidden layer concentration
        :param conc_out: Output layer concentration
        :param precision: Precision for equilibrium calculation
        :return: Arrays of affinities grouped by label (one per label)
        """
        # Output layer size and number of labels
        i_out = self.num_species - labels.shape[1]
        num_output = self.num_species - i_out
        num_labels = labels.shape[1]

        # Run network dynamics for all patterns
        states, _ = self.network_dynamics(self.Ks[0], patterns, conc_hidden, conc_out, precision)

        # Extract outputs (equilibrium states of the output species)
        outputs = states[:, i_out:]  # Shape: [N_patt, num_output]

        # Determine label indices for each pattern (assuming one-hot encoding)
        label_indices = np.argmax(labels, axis=1)  # Shape: [N_patt]

        # Initialize affinities for each label as lists
        affinities = [np.empty((0, num_output)) for _ in range(num_labels)]

        # Group outputs by their label using vectorized processing
        for label in range(num_labels):
            mask = (label_indices == label)  # Boolean mask for current label
            affinities[label] = outputs[mask]  # Collect outputs for this label

        return affinities
    def save(self, file_path):
        """
        Save the current ChemicalNetwork object to a file.
        
        :param file_path: Path to the file where the object should be saved.
        """
        with open(file_path, 'wb') as f:
            pickle.dump(self, f)

    @classmethod
    def load(cls, file_path):
        """
        Load a ChemicalNetwork object from a file.
        
        :param file_path: Path to the file from which the object should be loaded.
        :return: A ChemicalNetwork object.
        """
        with open(file_path, 'rb') as f:
            obj = pickle.load(f)
        return obj
    
def gen_patt_label(N_patt, D):
    # Randomly select indices from patterns_0
    # indices = np.random.randint(0, patterns_0.shape[0], size=N_patt)    
    # Balanced number of patterns 
    indices=np.zeros(N_patt,dtype=int)
    N1=int(N_patt/3)
    N2=2*N1
    indices[N1:]+=1
    indices[N2:]+=1
    selected_labels = labels_0[indices, :]
    selected_patterns = patterns_0[indices, :]
    # Apply log-normal scaling to the patterns
    scaling_factors = np.random.lognormal(mean=0, sigma=D, size=(N_patt, selected_patterns.shape[1]))
    scaled_patterns = selected_patterns * scaling_factors
    return scaled_patterns, selected_labels

# %% [markdown]
# ## Functions for Mutual Information and Plots

# %%
def compute_mutual_I(x, i, dx=0.01):
    # Combine all channels together
    x_combined = np.concatenate([x[0], x[1], x[2]])
    x_i = x[i]
    
    # Define histogram edges
    edges = np.arange(np.min(x_combined), np.max(x_combined) + dx, dx)
    
    # Compute histograms for the selected index and for the combined data
    counts_i, _ = np.histogram(x_i, bins=edges, density=False)
    counts_combined, _ = np.histogram(x_combined, bins=edges, density=False)
    
    # Total counts for normalization
    total = np.sum(counts_combined)
    if total == 0:
        return 0
    
    # Only consider bins where counts_combined > 0
    valid = counts_combined > 0
    # Compute p_i for valid bins
    p_i = counts_i[valid] / counts_combined[valid]
    # Relative frequency for the combined data in the valid bins
    p = counts_combined[valid] / total
    
    # Only include indices where the ratio is strictly between 0 and 1
    valid_indices = (p_i > 0) & (p_i < 1)
    p_i = p_i[valid_indices]
    p = p[valid_indices]
    
    # Compute the mutual information using the given formula
    numerator = np.sum(p * (p_i * np.log(p_i) + (1 - p_i) * np.log(1 - p_i)))
    normalization = np.log(3) - (2/3) * np.log(2)
  
    
    return 1+numerator/normalization


    



def generate_svg_plots(a_list, colors, lower_bound=-6, ID=""):
    """
    Generates two distinct SVG plots:
      1. A 3D scatter plot (with shadows projected onto the xy-plane).
      2. Histograms of the f_x, f_y, and f_z components (stacked vertically).
    
    In addition, calculates the entropy H_x of the x distribution for each dataset,
    for the combined distribution (all datasets concatenated),
    and for the combination of datasets 1 and 2.
    Then computes a mutual entropy as:
    
         M = H_x(combined) - (1/3*H_x(0) + 2/3*H_x(1,2))
    
    Both SVG outputs preserve editable text.
    
    Parameters:
      a_list       : list of numpy arrays, each with shape (n, 3) containing positive values.
      colors       : list of three color strings, one for each dataset.
      lower_bound  : fixed z-value for the xy-plane shadow and lower limit of the axes.
      scatter_filename : filename for the scatter plot SVG.
      hist_filename    : filename for the histograms SVG.
    """
    scatter_filename = f"SVGs/scatter_{ID}.svg"
    scatter_png = f"ChemClassifierWeb/images/scatter_{ID}.png"
    hist_filename = f"SVGs/histograms_{ID}.svg"
    hist_png = f"ChemClassifierWeb/images/histograms_{ID}.png"
   
    # Scaling factor: convert natural logs to base-10 logs.
    Dec = 1 / np.log(10)
    
    # Compute transformed data for each dataset.
    # Each a is assumed to have three columns: [f_x, f_y, f_z]
    all_x, all_y, all_z = [], [], []
    for a in a_list:
        x = Dec * np.log(a[:, 0])
        y = Dec * np.log(a[:, 1])
        z = Dec * np.log(a[:, 2])
        all_x.append(x)
        all_y.append(y)
        all_z.append(z)
  
    # Compute entropies for the x distributions.
    # H0: for first dataset; H1: for second; H2: for third.
 

    # Define tick positions from 0 to lower_bound in steps of -2.
    ticks = np.arange(0, lower_bound - 0.1, -1)  # subtract small value to ensure inclusion
    # Create tick labels: 0 is displayed as "1", other ticks as 10^{n}.
    labels = ["1" if tick == 0 else r'$10^{' + str(int(tick)) + '}$' for tick in ticks]
    font_size=28
    label_font=15

    # ======================================================
    # 1. Create the 3D Scatter Plot with Shadows and Export SVG
    # ======================================================
    fig_scatter = plt.figure(figsize=(10, 10))
    ax_scatter = fig_scatter.add_subplot(111, projection='3d')
   
    point_size = 10      # marker size for scatter points
    shadow_alpha = 0.05  # transparency for shadow points
    shadow_size = 1      # marker size for shadows
    
    # Plot each dataset in its color.
    for i, color in enumerate(colors):
        x = all_x[i]
        y = all_y[i]
        z = all_z[i]
        ax_scatter.scatter(x, y, z, color=color, s=point_size)
        # Plot shadow by re-plotting with z fixed at lower_bound.
        ax_scatter.scatter(x, y, zs=lower_bound, zdir='z', color=color, alpha=shadow_alpha, s=shadow_size)
    
    # Remove default axis labels; add custom axis names via text.
    ax_scatter.set_xlabel('')
    ax_scatter.set_ylabel('')
    ax_scatter.set_zlabel('')
    ax_scatter.text2D(0.27, 0.87, r'$f_x$', fontsize=font_size, transform=ax_scatter.transAxes)
    ax_scatter.text2D(0.73, 0.87, r'$f_y$', fontsize=font_size, transform=ax_scatter.transAxes)
    ax_scatter.text2D(1.0, 0.5, r'$f_z$', fontsize=font_size, transform=ax_scatter.transAxes)
    
    # Set limits for each axis.
    ax_scatter.set_xlim(lower_bound, 0)
    ax_scatter.set_ylim(lower_bound, 0)
    ax_scatter.set_zlim(lower_bound, 0)
    
    # Apply same ticks/labels on all three axes.
    ax_scatter.set_xticks(ticks)
    ax_scatter.set_xticklabels(labels, fontsize=label_font)
    ax_scatter.set_yticks(ticks)
    ax_scatter.set_yticklabels(labels,fontsize=label_font)
    ax_scatter.set_zticks(ticks)
    ax_scatter.set_zticklabels(labels,fontsize=label_font)
    
    ax_scatter.view_init(elev=20, azim=45)
    #ax_scatter.set_title("3D Scatter Plot with Shadows", fontsize=16)
    #fig_scatter.tight_layout()
    # Export scatter plot to SVG.
    print(scatter_filename)
    fig_scatter.savefig(scatter_filename, facecolor='none', transparent=True, format="svg")
    fig_scatter.savefig(scatter_png, facecolor='none', transparent=True, format="png")
    plt.close(fig_scatter)
    
    # ======================================================
    # 2. Create the Histograms Plot and Export SVG
    # ======================================================
    # Create a figure with three vertically stacked subplots.
    fig_hist = plt.figure(figsize=(8, 16))
    ax_hist_x = fig_hist.add_subplot(311)
    ax_hist_y = fig_hist.add_subplot(312)
    ax_hist_z = fig_hist.add_subplot(313)

    bins = 30  # number of bins for the histograms.
    
    # Plot histogram for f_x.
    for i, color in enumerate(colors):
        ax_hist_x.hist(all_x[i], bins=bins, color=color,density=True, alpha=0.7)
    # Plot histogram for f_y.
    for i, color in enumerate(colors):
        ax_hist_y.hist(all_y[i], bins=bins, color=color,density=True, alpha=0.7)
 
    for i, color in enumerate(colors):
        ax_hist_z.hist(all_z[i], bins=bins, color=color,density=True, alpha=0.7)
    
 
    for ax_hist in [ax_hist_x, ax_hist_y, ax_hist_z]:
        ax_hist.set_xlim(lower_bound, 0)
        ax_hist.set_xticks(ticks)
        ax_hist.set_xticklabels(labels, fontsize=label_font)
  
    
    ax_hist_x.text(0.05, 0.9, r'$f_x$', fontsize=font_size, transform=ax_hist_x.transAxes)
    ax_hist_y.text(0.05, 0.9, r'$f_y$', fontsize=font_size, transform=ax_hist_y.transAxes)
    ax_hist_z.text(0.05, 0.9, r'$f_z$', fontsize=font_size, transform=ax_hist_z.transAxes)

    mutual_information_x= compute_mutual_I(all_x,0)
    mutual_information_y= compute_mutual_I(all_y,1)
    mutual_information_z= compute_mutual_I(all_z,2)


    ax_hist_x.text(0.6, 0.9, f'$I_X = {mutual_information_x:.2f}$', fontsize=font_size, color='red', transform=ax_hist_x.transAxes)
    ax_hist_y.text(0.6, 0.9, f'$I_Y = {mutual_information_y:.2f}$', fontsize=font_size, color='blue', transform=ax_hist_y.transAxes)
    ax_hist_z.text(0.6, 0.9, f'$I_Z = {mutual_information_z:.2f}$', fontsize=font_size, color='green', transform=ax_hist_z.transAxes)

    
    fig_hist.tight_layout()
  
    fig_hist.savefig(hist_filename, format="svg")
    fig_hist.savefig(hist_png, format="png")
    plt.close(fig_hist)
    return mutual_information_x, mutual_information_y, mutual_information_z
    # Optionally, display the SVG files in a Jupyter Notebook.
    # disp.display(disp.SVG(filename=scatter_filename))
    # disp.display(disp.SVG(filename=hist_filename))

# %% [markdown]
# ## Initialize parameters

# %%
# Make sure ChemicalNetwork, gen_patt_label, generate_svg_plots are imported or defined appropriately

N_species = 15
N_inp = 6
N_out = 3

N_desc = 50 + 1
Conc_hidden = 1.
Conc_out = 1.
mean = -0.0  # mean of the normal distribution used when cloning (0.02)
sigma = 0.5  # variance used when cloning
sigma_0 = np.sqrt(2.)  # variance of the starting patterns' distribution 
mean_0 = -1.

pp = 0.0  # pp=0 for digital labels
labels_0 = np.array([
    [Conc_out * (10 - pp) / 10., Conc_out * pp / 10., Conc_out * pp / 10.],
    [Conc_out * pp / 10., Conc_out * (10 - pp) / 10., Conc_out * pp / 10.],
    [Conc_out * pp / 10., Conc_out * pp / 10., Conc_out * (10 - pp) / 10.]
])

precision = np.power(10., -6)

noise_scan=range(10,121,5)
drift_scan = [0,2,4,8]  # you can add more drift values if needed
cocktail_scan=range(1,49)

# %% [markdown]
# ## Generate scatterplots and histograms

# %%
# Simulation parameters

colors = ['red', 'blue', 'green']


for drift in drift_scan:
    for cocktail_set in cocktail_scan:
           
        pattern_filename = f"PKLs/patterns_F{cocktail_set}.pkl"
        with open(pattern_filename, 'rb') as f:
            patterns_0 = pickle.load(f)
            
        ns_list = []
        mi_x_list = []
        mi_y_list = []
        mi_z_list = []
            
        for noise in noise_scan:
            NS_ratio = noise * 0.01
            D = sigma_0 * NS_ratio
            ns_list.append(NS_ratio)
                
            ID = f"{cocktail_set}_{drift}_{noise}"
            CN_filename = f"PKLs/CN_F{ID}.pkl"
            CN = ChemicalNetwork.load(CN_filename)
            print(f"Processing {CN_filename}")
                
            # Generate test patterns and labels
            patterns_scatter, labels_scatter = gen_patt_label(4200, D)
            a1, a2, a3 = CN.test_model(patterns_scatter, labels_scatter,
                                             CN.conc_hidden, CN.conc_out, precision)
                
                # Generate plots and/or compute mutual information values
            mi_x, mi_y, mi_z = generate_svg_plots([a1, a2, a3], colors, ID=ID)
                # Alternatively:
# Out:
# Processing PKLs/CN_F1_0_10.pkl
# SVGs/scatter_1_0_10.svg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 34
#      30 a1, a2, a3 = CN.test_model(patterns_scatter, labels_scatter,
#      31                                  CN.conc_hidden, CN.conc_out, precision)
#      33     # Generate plots and/or compute mutual information values
# ---> 34 mi_x, mi_y, mi_z = generate_svg_plots([a1, a2, a3], colors, ID=ID)
#      35     # Alternatively:
#
# Cell In[3], line 187, in generate_svg_plots(a_list, colors, lower_bound, ID)
#     182 ax_hist_z.text(0.6, 0.9, f'$I_Z = {mutual_information_z:.2f}$', fontsize=font_size, color='green', transform=ax_hist_z.transAxes)
#     185 fig_hist.tight_layout()
# --> 187 fig_hist.savefig(hist_filename, format="svg")
#     188 fig_hist.savefig(hist_png, format="png")
#     189 plt.close(fig_hist)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\backends\backend_svg.py:1340, in FigureCanvasSVG.print_svg(self, filename, bbox_inches_restore, metadata)
#    1308 def print_svg(self, filename, *, bbox_inches_restore=None, metadata=None):
#    1309     """
#    1310     Parameters
#    1311     ----------
#    (...)   1338         __ DC_
#    1339     """
# -> 1340     with cbook.open_file_cm(filename, "w", encoding="utf-8") as fh:
#    1341         if not cbook.file_requires_unicode(fh):
#    1342             fh = codecs.getwriter('utf-8')(fh)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\cbook.py:560, in open_file_cm(path_or_file, mode, encoding)
#     558 def open_file_cm(path_or_file, mode="r", encoding=None):
#     559     r"""Pass through file objects and context-manage path-likes."""
# --> 560     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     561     return fh if opened else contextlib.nullcontext(fh)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\cbook.py:546, in to_filehandle(fname, flag, return_opened, encoding)
#     544         fh = bz2.BZ2File(fname, flag)
#     545     else:
# --> 546         fh = open(fname, flag, encoding=encoding)
#     547     opened = True
#     548 elif hasattr(fname, 'seek'):
#
# File <frozen codecs>:189, in __init__(self, errors)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualize Chemical Networks

# %%
import numpy as np
import random
import itertools
from IPython.display import SVG, display

def permutation_metric(perm, W):
    """
    Compute the metric for a candidate permutation of layer2 vertices.
    
    Parameters:
      perm : a tuple of 6 indices (a permutation of 0,1,2,3,4,5) indicating the desired order 
             for the six vertices originally at indices 6 to 11.
      W    : a 12x12 weight matrix (e.g. the submatrix of adj_matrix for indices 0 to 11)
      
    The final ordering is defined as:
      final_order = [0,1,2,3,4,5] + [6+perm[0], 6+perm[1], ..., 6+perm[5]]
    The metric is:
      sum_{0 <= i < j < 12} W[ final_order[i], final_order[j] ] * ( ((j - i) mod 6) ** 2 )
      
    Returns:
      The computed metric (a scalar).
    """
    # Fixed part: layer1 indices:
    fixed = list(range(6))
    # Permuted part for layer2:
    permuted = [6 + p for p in perm]
    final_order = fixed + permuted
    metric = 0.0
    W0=10

    # Loop over all pairs (i,j) with i < j among 12 vertices:
    for idx_i in range(6):
        for idx_j in range(6, 12):
            diff = (idx_i % 6-idx_j % 6)**2  
            metric += W[final_order[idx_i], final_order[idx_j]]*diff  
    for idx_i in range(6, 12):
        for idx_j in range(idx_i+1, 12):
            diff = (idx_i % 6-idx_j % 6)**2  
            metric += W0*W[final_order[idx_i], final_order[idx_j]]*diff  
    return metric

# -------------------------------------------



for cocktail_set in cocktail_scan:
    for drift in drift_scan:
        for noise in noise_scan:
            ID=f"2_F{cocktail_set}_{drift}_{noise}"
            filename = f"PKLs/CN{ID}.pkl"
            CN = ChemicalNetwork.load(filename)
            
            K_cut_off = 1
            adj_matrix = CN.Ks[0].copy()  # 15x15 matrix
            adj_matrix[adj_matrix < K_cut_off] = 0
            
            # -------- Parameters for layout ----------
            width, height = 600, 600
            y_positions = [100, 300, 500]  # layer1 at top, layer3 at bottom

            def get_x_positions(n, margin=50):
                return np.linspace(margin, width - margin, n)
            
            # Get positions for layer1 and layer3:
            x_positions_layer1 = get_x_positions(6, margin=80)
            x_positions_layer3 = get_x_positions(3, margin=160)
            # For layer2, get the initial x positions (unsorted).
            x_positions_layer2 = get_x_positions(6)
            
            # ----------------- Permutation Search -----------------
            # We use the submatrix for the first two layers (indices 0 to 11)
            norm = 12 / np.log(np.max(adj_matrix) + 1)
            W = adj_matrix[0:12, 0:12]
            W = norm*np.log(W + 1)
            
            best_perm = None
            best_metric = np.inf
            for perm in itertools.permutations(range(6)):
                m = permutation_metric(perm, W)
                if m < best_metric:
                    best_metric = m
                    best_perm = perm
            print("Noise:", noise, "Best permutation for layer2:", best_perm, "Metric =", best_metric)
        
            # ----------------- Apply Permutation to Layer2 Positions -----------------
            # Reorder the x positions for layer2 according to best_perm.
            permuted = [6 + p for p in best_perm]
            best_order = np.array(list(range(6)) + permuted + list(range(12,15)))
            new_adj = adj_matrix[np.ix_(best_order, best_order)]
            

            
            # ----------------- Build the List of Vertex Positions -----------------
            positions = []
            # Layer1 (indices 0-5):
            for x in x_positions_layer1:
                positions.append((x, y_positions[0]))
            # Layer2 (indices 6-11):
            for x in x_positions_layer2:
                positions.append((x, y_positions[1]))
            # Layer3 (indices 12-14):
            for x in x_positions_layer3:
                positions.append((x, y_positions[2]))
            
            # ----------------- Colors for Vertices -----------------
            def hex_color(r, g, b):
                return f"#{r:02x}{g:02x}{b:02x}"
            
            # Layer1: Gradient from violet to orange.
            layer1_colors = []
            for i in range(6):
                ratio = i / 5
                r = int(138 + ratio * (255 - 138))
                g = int(43 + ratio * (165 - 43))
                b = int(226 + ratio * (0 - 226))
                layer1_colors.append(hex_color(r, g, b))
            # Layer2: Random shades of gray.
            layer2_colors = []
            for _ in range(6):
                v = random.randint(100, 200)
                layer2_colors.append(hex_color(v, v, v))
            # Layer3: Fixed colors.
            layer3_colors = ['red', 'blue', 'green']
            vertex_colors = layer1_colors + layer2_colors + layer3_colors
            
            # ----------------- SVG Generation -----------------
            edge_scale = 1
            
            svg_lines = []
            svg_lines.append(f'<svg xmlns="http://www.w3.org/2000/svg" width="{width}" height="{height}">')
            
            # Draw edges (for each pair i<j if weight>0, over all 15 vertices).
            for i in range(15):
                for j in range(i+1, 15):
                    weight = norm * np.log(new_adj[i, j] + 1)
                    if weight > 0:
                        x1, y1 = positions[i]
                        x2, y2 = positions[j]
                        stroke_width = weight * edge_scale
                        svg_lines.append(f'<line x1="{x1}" y1="{y1}" x2="{x2}" y2="{y2}" stroke="darkgrey" stroke-width="{stroke_width:.2f}" />')
            
            # Draw vertices as circles.
            for i, (x, y) in enumerate(positions):
                color = vertex_colors[i]
                if i < 12:
                    radius = 25
                    svg_lines.append(f'<circle cx="{x}" cy="{y}" r="{radius}" fill="{color}" stroke="black" stroke-width="2" />')
                else:
                    radius = 22
                    svg_lines.append(f'<circle cx="{x}" cy="{y}" r="{radius}" fill="{color}" stroke="black" stroke-width="2" />')
                    label = ['x', 'y', 'z'][i - 12]
                    svg_lines.append(f'<text x="{x}" y="{y+4}" font-size="26" text-anchor="middle" fill="white" font-weight="bold">{label}</text>')
            
            svg_lines.append('</svg>')
            svg_output = "\n".join(svg_lines)
            
            # Save and display the SVG.
            filename_svg = f"ChemClassifierWeb/images/CDN_{ID}.svg"
            with open(filename_svg, "w") as f:
                 f.write(svg_output)
            # display(SVG(svg_output))
            print("Max weight:", np.max(adj_matrix))
# Out:
# Noise: 10 Best permutation for layer2: (3, 4, 0, 5, 2, 1) Metric = 648.2540557760083
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (4, 1, 2, 5, 3, 0) Metric = 743.8442796192161
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (0, 1, 3, 5, 4, 2) Metric = 604.8713999923057
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (1, 0, 5, 3, 2, 4) Metric = 600.5317736506483
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (3, 5, 0, 1, 4, 2) Metric = 986.5516821539414
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (3, 1, 0, 2, 4, 5) Metric = 631.2748810944045
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (2, 3, 4, 5, 1, 0) Metric = 823.3814806429892
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (5, 2, 3, 4, 1, 0) Metric = 741.565159857507
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (3, 0, 1, 5, 4, 2) Metric = 557.9058464378511
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (5, 3, 0, 2, 4, 1) Metric = 484.5009391692282
# Max weight: 10000.0
# Noise: 60 Best permutation for layer2: (5, 1, 4, 2, 0, 3) Metric = 1181.6077379153471
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (2, 3, 0, 5, 4, 1) Metric = 1392.9449423259089
# Max weight: 10000.0
# Noise: 70 Best permutation for layer2: (2, 0, 1, 4, 3, 5) Metric = 893.7425032155937
# Max weight: 10000.0
# Noise: 75 Best permutation for layer2: (4, 1, 0, 3, 5, 2) Metric = 1167.8717293223974
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (1, 2, 0, 3, 5, 4) Metric = 1576.6703263709442
# Max weight: 10000.0
# Noise: 85 Best permutation for layer2: (0, 1, 2, 5, 4, 3) Metric = 849.9259573252539
# Max weight: 10000.0
# Noise: 90 Best permutation for layer2: (1, 3, 0, 4, 5, 2) Metric = 1072.2669041093434
# Max weight: 8136.7889161400635
# Noise: 95 Best permutation for layer2: (0, 2, 4, 3, 5, 1) Metric = 651.7223752139793
# Max weight: 10000.0
# Noise: 100 Best permutation for layer2: (0, 5, 4, 2, 1, 3) Metric = 912.385700627161
# Max weight: 10000.0
# Noise: 105 Best permutation for layer2: (1, 5, 2, 4, 3, 0) Metric = 988.7898136490909
# Max weight: 10000.0
# Noise: 110 Best permutation for layer2: (5, 3, 1, 2, 0, 4) Metric = 2509.1282639915344
# Max weight: 10000.0
# Noise: 115 Best permutation for layer2: (5, 0, 3, 1, 4, 2) Metric = 1755.7392814446357
# Max weight: 10000.0
# Noise: 120 Best permutation for layer2: (1, 4, 0, 3, 2, 5) Metric = 1875.9286178189745
# Max weight: 6217.901417954491
# Noise: 10 Best permutation for layer2: (2, 5, 0, 4, 3, 1) Metric = 1196.471996121705
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (0, 2, 5, 1, 4, 3) Metric = 202.2422776595206
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (4, 0, 5, 3, 2, 1) Metric = 357.3183174322537
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (5, 3, 4, 1, 0, 2) Metric = 166.6554967259912
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (5, 1, 4, 2, 0, 3) Metric = 268.1381026586598
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (4, 5, 1, 2, 3, 0) Metric = 209.4056556035433
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (5, 3, 2, 4, 0, 1) Metric = 382.7338105309939
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (1, 0, 5, 4, 2, 3) Metric = 559.2907901070803
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (2, 5, 3, 4, 0, 1) Metric = 150.53093076972743
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (2, 3, 4, 5, 0, 1) Metric = 236.53030520705937
# Max weight: 10000.0
# Noise: 60 Best permutation for layer2: (1, 4, 0, 5, 2, 3) Metric = 456.66664692610163
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (5, 2, 1, 0, 3, 4) Metric = 289.63086057623815
# Max weight: 9873.723635452803
# Noise: 70 Best permutation for layer2: (5, 2, 0, 4, 1, 3) Metric = 416.91775121487933
# Max weight: 9096.619077260853
# Noise: 75 Best permutation for layer2: (5, 4, 1, 0, 2, 3) Metric = 610.8334126074592
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (5, 0, 1, 3, 2, 4) Metric = 779.6410690113408
# Max weight: 8285.288866398061
# Noise: 85 Best permutation for layer2: (3, 2, 5, 1, 4, 0) Metric = 345.51143770556
# Max weight: 6515.323020122322
# Noise: 90 Best permutation for layer2: (2, 0, 3, 4, 1, 5) Metric = 280.30037758058205
# Max weight: 7749.31933309652
# Noise: 95 Best permutation for layer2: (0, 3, 1, 4, 2, 5) Metric = 458.80003798120714
# Max weight: 10000.0
# Noise: 100 Best permutation for layer2: (0, 3, 5, 2, 1, 4) Metric = 527.7681733271918
# Max weight: 2750.314242283682
# Noise: 105 Best permutation for layer2: (1, 2, 3, 4, 0, 5) Metric = 335.6647367103723
# Max weight: 10000.0
# Noise: 110 Best permutation for layer2: (2, 4, 0, 3, 1, 5) Metric = 145.096658491036
# Max weight: 3794.3155612387636
# Noise: 115 Best permutation for layer2: (5, 0, 4, 2, 1, 3) Metric = 248.21179668950808
# Max weight: 5274.570857037683
# Noise: 120 Best permutation for layer2: (4, 1, 5, 0, 2, 3) Metric = 302.60174890649995
# Max weight: 10000.0
# Noise: 10 Best permutation for layer2: (2, 4, 5, 0, 3, 1) Metric = 177.6327505527089
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (0, 2, 3, 4, 5, 1) Metric = 123.96729003317922
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (5, 3, 2, 1, 0, 4) Metric = 173.91636874273405
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (1, 3, 4, 5, 0, 2) Metric = 121.69829047618708
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (0, 3, 2, 4, 5, 1) Metric = 131.92240038389946
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (5, 2, 3, 4, 0, 1) Metric = 21.25195415893487
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (2, 0, 1, 5, 4, 3) Metric = 197.7767926785348
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (1, 0, 3, 5, 4, 2) Metric = 23.557378046611007
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (1, 4, 2, 0, 5, 3) Metric = 835.2137501942486
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (0, 5, 2, 4, 1, 3) Metric = 237.17687376062287
# Max weight: 7612.845931008225
# Noise: 60 Best permutation for layer2: (4, 5, 1, 3, 0, 2) Metric = 253.301693142054
# Max weight: 9984.186362462364
# Noise: 65 Best permutation for layer2: (0, 5, 2, 4, 3, 1) Metric = 88.98175984804692
# Max weight: 9814.76708192422
# Noise: 70 Best permutation for layer2: (0, 5, 1, 3, 2, 4) Metric = 254.92702675239642
# Max weight: 9979.614068254627
# Noise: 75 Best permutation for layer2: (3, 2, 5, 1, 0, 4) Metric = 124.12162053025051
# Max weight: 8005.584722013717
# Noise: 80 Best permutation for layer2: (2, 4, 5, 0, 3, 1) Metric = 73.81331742323279
# Max weight: 5305.037961662952
# Noise: 85 Best permutation for layer2: (0, 5, 2, 1, 3, 4) Metric = 242.59074147700716
# Max weight: 4668.501709863371
# Noise: 90 Best permutation for layer2: (0, 3, 1, 4, 2, 5) Metric = 188.37162016204474
# Max weight: 10000.0
# Noise: 95 Best permutation for layer2: (0, 1, 5, 3, 2, 4) Metric = 173.87077992486783
# Max weight: 5710.117041910114
# Noise: 100 Best permutation for layer2: (0, 4, 1, 2, 3, 5) Metric = 247.22978958855103
# Max weight: 1190.5592672495984
# Noise: 105 Best permutation for layer2: (0, 1, 4, 2, 3, 5) Metric = 152.6211466333486
# Max weight: 7755.331289960124
# Noise: 110 Best permutation for layer2: (1, 3, 0, 4, 2, 5) Metric = 455.8322845031406
# Max weight: 10000.0
# Noise: 115 Best permutation for layer2: (2, 5, 3, 1, 0, 4) Metric = 197.74326126521618
# Max weight: 2214.560040183976
# Noise: 120 Best permutation for layer2: (0, 3, 4, 1, 5, 2) Metric = 231.1025038602156
# Max weight: 8310.61711476008
# Noise: 10 Best permutation for layer2: (3, 2, 5, 4, 1, 0) Metric = 88.33353151933439
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (0, 4, 2, 3, 1, 5) Metric = 248.26209306179464
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (5, 0, 2, 4, 1, 3) Metric = 0.0
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (4, 0, 3, 1, 2, 5) Metric = 0.0
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (0, 1, 5, 3, 2, 4) Metric = 23.267439196409292
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (0, 2, 1, 4, 3, 5) Metric = 23.707687772910585
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (5, 0, 1, 2, 3, 4) Metric = 0.0
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (5, 0, 2, 1, 3, 4) Metric = 24.0
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (4, 0, 5, 2, 1, 3) Metric = 205.55789919541346
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (5, 0, 2, 1, 3, 4) Metric = 19.053633275083417
# Max weight: 2719.7408204826897
# Noise: 60 Best permutation for layer2: (0, 1, 3, 5, 2, 4) Metric = 177.0279123070406
# Max weight: 2909.767648627831
# Noise: 65 Best permutation for layer2: (1, 2, 5, 0, 3, 4) Metric = 131.89852616076712
# Max weight: 7338.345874641102
# Noise: 70 Best permutation for layer2: (5, 0, 2, 3, 1, 4) Metric = 0.0
# Max weight: 6445.82483104266
# Noise: 75 Best permutation for layer2: (0, 2, 3, 1, 4, 5) Metric = 14.943814774851381
# Max weight: 4734.502592552793
# Noise: 80 Best permutation for layer2: (1, 4, 2, 3, 0, 5) Metric = 112.27816136650375
# Max weight: 2378.015237756928
# Noise: 85 Best permutation for layer2: (4, 2, 1, 0, 3, 5) Metric = 59.3548068986808
# Max weight: 1701.162954574336
# Noise: 90 Best permutation for layer2: (1, 2, 3, 4, 0, 5) Metric = 140.36976742007027
# Max weight: 311.64624132114955
# Noise: 95 Best permutation for layer2: (2, 3, 4, 0, 5, 1) Metric = 8.318729263959446
# Max weight: 541.7159603067182
# Noise: 100 Best permutation for layer2: (1, 3, 2, 0, 4, 5) Metric = 168.09597390517536
# Max weight: 398.95558428714145
# Noise: 105 Best permutation for layer2: (0, 2, 4, 1, 3, 5) Metric = 98.63391510322924
# Max weight: 331.670702956652
# Noise: 110 Best permutation for layer2: (2, 0, 1, 4, 3, 5) Metric = 16.821562164944993
# Max weight: 48.42070397099955
# Noise: 115 Best permutation for layer2: (0, 2, 1, 5, 3, 4) Metric = 79.10606000466423
# Max weight: 285.8915424150177
# Noise: 120 Best permutation for layer2: (0, 3, 2, 1, 4, 5) Metric = 155.26781344388635
# Max weight: 64.33406993989402
# Noise: 10 Best permutation for layer2: (3, 0, 2, 5, 1, 4) Metric = 579.6117667000294
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (5, 4, 1, 0, 3, 2) Metric = 464.4213885646689
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (5, 1, 0, 4, 3, 2) Metric = 661.7600035746501
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (0, 5, 2, 1, 3, 4) Metric = 619.6443547711663
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (4, 1, 2, 3, 0, 5) Metric = 831.2515193742695
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (4, 2, 0, 3, 5, 1) Metric = 571.2009682454453
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (0, 4, 1, 5, 2, 3) Metric = 693.9407354196358
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (4, 3, 1, 0, 5, 2) Metric = 1029.9922434795074
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (4, 2, 1, 0, 3, 5) Metric = 719.3707009578136
# Max weight: 6812.230883768878
# Noise: 55 Best permutation for layer2: (2, 5, 3, 1, 4, 0) Metric = 1300.089840502577
# Max weight: 10000.0
# Noise: 60 Best permutation for layer2: (2, 3, 5, 4, 0, 1) Metric = 695.5657576756328
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (0, 4, 5, 1, 2, 3) Metric = 872.6891796218961
# Max weight: 10000.0
# Noise: 70 Best permutation for layer2: (1, 2, 3, 4, 0, 5) Metric = 672.8496193412587
# Max weight: 10000.0
# Noise: 75 Best permutation for layer2: (5, 3, 4, 2, 1, 0) Metric = 599.6078085277148
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (4, 2, 1, 0, 3, 5) Metric = 758.857977478468
# Max weight: 10000.0
# Noise: 85 Best permutation for layer2: (1, 4, 5, 0, 3, 2) Metric = 1435.3223617874985
# Max weight: 10000.0
# Noise: 90 Best permutation for layer2: (2, 3, 0, 1, 5, 4) Metric = 1665.3302601909718
# Max weight: 10000.0
# Noise: 95 Best permutation for layer2: (4, 0, 5, 1, 2, 3) Metric = 2275.2858155771
# Max weight: 10000.0
# Noise: 100 Best permutation for layer2: (2, 0, 4, 5, 3, 1) Metric = 948.2608292043362
# Max weight: 10000.0
# Noise: 105 Best permutation for layer2: (1, 0, 5, 2, 4, 3) Metric = 1198.3589244038296
# Max weight: 8579.482039199564
# Noise: 110 Best permutation for layer2: (5, 0, 3, 4, 1, 2) Metric = 1453.2739656070669
# Max weight: 7051.279958770923
# Noise: 115 Best permutation for layer2: (4, 3, 1, 2, 5, 0) Metric = 1746.657830886028
# Max weight: 10000.0
# Noise: 120 Best permutation for layer2: (1, 2, 0, 4, 5, 3) Metric = 1179.8008716182044
# Max weight: 9914.82683171714
# Noise: 10 Best permutation for layer2: (2, 3, 1, 0, 4, 5) Metric = 250.65976822845204
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (1, 0, 3, 4, 5, 2) Metric = 306.6801694458778
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (1, 4, 3, 5, 0, 2) Metric = 469.0498556008951
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (2, 0, 5, 3, 4, 1) Metric = 196.6497264418735
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (3, 4, 5, 0, 1, 2) Metric = 445.3408406906028
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (1, 5, 4, 3, 0, 2) Metric = 190.98997554793863
# Max weight: 6971.449600411658
# Noise: 40 Best permutation for layer2: (5, 4, 2, 0, 3, 1) Metric = 613.6504734410908
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (3, 0, 1, 2, 4, 5) Metric = 716.1931351215262
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (2, 0, 4, 1, 3, 5) Metric = 1429.7478456215526
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (3, 1, 2, 0, 4, 5) Metric = 332.1792638635789
# Max weight: 10000.0
# Noise: 60 Best permutation for layer2: (0, 4, 2, 3, 5, 1) Metric = 1219.6710038833164
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (1, 4, 5, 0, 3, 2) Metric = 399.3096150878991
# Max weight: 10000.0
# Noise: 70 Best permutation for layer2: (2, 1, 4, 3, 0, 5) Metric = 298.04369605753345
# Max weight: 2556.6929880517996
# Noise: 75 Best permutation for layer2: (5, 0, 1, 3, 2, 4) Metric = 314.0548066490603
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (2, 4, 5, 3, 0, 1) Metric = 406.9621961161478
# Max weight: 10000.0
# Noise: 85 Best permutation for layer2: (3, 4, 1, 0, 5, 2) Metric = 433.78049717376257
# Max weight: 3096.819995470436
# Noise: 90 Best permutation for layer2: (3, 2, 4, 0, 1, 5) Metric = 169.83622718904738
# Max weight: 10000.0
# Noise: 95 Best permutation for layer2: (1, 3, 5, 4, 2, 0) Metric = 295.4672117802786
# Max weight: 10000.0
# Noise: 100 Best permutation for layer2: (2, 0, 4, 1, 3, 5) Metric = 536.1069997745387
# Max weight: 10000.0
# Noise: 105 Best permutation for layer2: (4, 5, 0, 3, 1, 2) Metric = 363.1911490183774
# Max weight: 10000.0
# Noise: 110 Best permutation for layer2: (1, 0, 5, 3, 4, 2) Metric = 626.899188760994
# Max weight: 9127.197413679985
# Noise: 115 Best permutation for layer2: (4, 0, 5, 3, 2, 1) Metric = 49.26624069965577
# Max weight: 7784.537653730421
# Noise: 120 Best permutation for layer2: (0, 1, 4, 2, 5, 3) Metric = 424.0595059080224
# Max weight: 10000.0
# Noise: 10 Best permutation for layer2: (3, 1, 5, 2, 0, 4) Metric = 52.9114591423668
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (2, 5, 1, 0, 3, 4) Metric = 107.70385507589167
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (1, 5, 3, 2, 0, 4) Metric = 388.77193500335613
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (1, 3, 4, 2, 0, 5) Metric = 98.38880332222999
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (1, 4, 5, 0, 3, 2) Metric = 203.13061414319003
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (3, 5, 0, 2, 4, 1) Metric = 456.9788166112856
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (4, 5, 3, 0, 2, 1) Metric = 11.563973853347896
# Max weight: 6615.2379572057025
# Noise: 45 Best permutation for layer2: (3, 0, 2, 1, 5, 4) Metric = 275.43292567804855
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (2, 5, 1, 0, 4, 3) Metric = 177.86004801182406
# Max weight: 6205.916274968898
# Noise: 55 Best permutation for layer2: (3, 0, 5, 4, 2, 1) Metric = 213.9341795431298
# Max weight: 7256.930587515768
# Noise: 60 Best permutation for layer2: (0, 1, 4, 3, 2, 5) Metric = 323.69610698272925
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (5, 1, 2, 3, 0, 4) Metric = 319.76357911854086
# Max weight: 10000.0
# Noise: 70 Best permutation for layer2: (3, 0, 4, 1, 5, 2) Metric = 273.3697829440005
# Max weight: 8566.876314465364
# Noise: 75 Best permutation for layer2: (1, 5, 0, 4, 2, 3) Metric = 182.32644801705146
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (0, 2, 1, 3, 5, 4) Metric = 338.0154527163314
# Max weight: 9654.215536030999
# Noise: 85 Best permutation for layer2: (4, 1, 0, 2, 3, 5) Metric = 281.0152842605887
# Max weight: 9670.879128129382
# Noise: 90 Best permutation for layer2: (0, 1, 4, 5, 3, 2) Metric = 212.90234388049464
# Max weight: 2096.9769702059148
# Noise: 95 Best permutation for layer2: (1, 2, 3, 0, 4, 5) Metric = 43.46412764513679
# Max weight: 402.5097490200679
# Noise: 100 Best permutation for layer2: (5, 4, 1, 3, 2, 0) Metric = 332.96573549612117
# Max weight: 9277.633769361652
# Noise: 105 Best permutation for layer2: (1, 2, 0, 3, 5, 4) Metric = 135.05392869075905
# Max weight: 28.20988776303255
# Noise: 110 Best permutation for layer2: (2, 5, 3, 1, 0, 4) Metric = 193.8096044644057
# Max weight: 6549.589620089751
# Noise: 115 Best permutation for layer2: (3, 2, 5, 1, 0, 4) Metric = 166.28628471942187
# Max weight: 4804.796455782433
# Noise: 120 Best permutation for layer2: (0, 1, 2, 3, 4, 5) Metric = 33.32917548424768
# Max weight: 6394.239275883753
# Noise: 10 Best permutation for layer2: (3, 5, 2, 1, 4, 0) Metric = 164.49122185042617
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (4, 5, 0, 3, 2, 1) Metric = 227.32310298109377
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (5, 3, 0, 1, 2, 4) Metric = 11.797762435118411
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (0, 1, 3, 2, 4, 5) Metric = 56.81958343761181
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (2, 0, 3, 1, 4, 5) Metric = 104.78637578480419
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (3, 0, 5, 2, 4, 1) Metric = 54.51281034343069
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (0, 3, 4, 2, 5, 1) Metric = 9.387563138661172
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (5, 1, 0, 2, 3, 4) Metric = 45.11301956687923
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (2, 1, 3, 0, 4, 5) Metric = 0.0
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (4, 0, 5, 3, 1, 2) Metric = 71.65004492408957
# Max weight: 3822.9805091463213
# Noise: 60 Best permutation for layer2: (4, 2, 3, 1, 5, 0) Metric = 0.0
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (5, 0, 2, 3, 1, 4) Metric = 8.923312312664944
# Max weight: 3260.724723634169
# Noise: 70 Best permutation for layer2: (0, 2, 3, 5, 4, 1) Metric = 0.0
# Max weight: 192.80768048394654
# Noise: 75 Best permutation for layer2: (0, 2, 3, 1, 4, 5) Metric = 0.0
# Max weight: 94.51338768177054
# Noise: 80 Best permutation for layer2: (5, 1, 2, 0, 3, 4) Metric = 0.0
# Max weight: 848.8997063150043
# Noise: 85 Best permutation for layer2: (0, 1, 2, 4, 3, 5) Metric = 0.0
# Max weight: 1064.7277370046793
# Noise: 90 Best permutation for layer2: (4, 0, 1, 2, 3, 5) Metric = 0.0
# Max weight: 395.44691584809874
# Noise: 95 Best permutation for layer2: (4, 0, 1, 3, 5, 2) Metric = 0.0
# Max weight: 78.54004783734409
# Noise: 100 Best permutation for layer2: (5, 1, 0, 2, 3, 4) Metric = 0.0
# Max weight: 4943.188002832218
# Noise: 105 Best permutation for layer2: (2, 0, 1, 3, 5, 4) Metric = 0.0
# Max weight: 218.33164000503376
# Noise: 110 Best permutation for layer2: (0, 1, 2, 3, 4, 5) Metric = 0.0
# Max weight: 7.3853878120399346
# Noise: 115 Best permutation for layer2: (1, 2, 3, 0, 4, 5) Metric = 0.0
# Max weight: 18.972781638159752
# Noise: 120 Best permutation for layer2: (4, 2, 0, 1, 3, 5) Metric = 0.0
# Max weight: 263.5669458837771
# Noise: 10 Best permutation for layer2: (5, 4, 0, 2, 3, 1) Metric = 279.95964246289344
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (5, 3, 1, 4, 0, 2) Metric = 745.9822279981558
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (4, 0, 3, 2, 1, 5) Metric = 638.0531867800122
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (0, 4, 3, 5, 2, 1) Metric = 751.2342059920878
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (4, 5, 1, 2, 0, 3) Metric = 735.462767844668
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (3, 0, 5, 1, 4, 2) Metric = 517.5615005212019
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (5, 3, 4, 1, 2, 0) Metric = 1480.078452766822
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (0, 5, 3, 2, 1, 4) Metric = 628.2190245872155
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (5, 1, 0, 4, 2, 3) Metric = 853.7306898097702
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (1, 3, 4, 5, 0, 2) Metric = 966.015471617143
# Max weight: 10000.0
# Noise: 60 Best permutation for layer2: (4, 0, 3, 5, 2, 1) Metric = 1288.490461424707
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (1, 4, 2, 0, 5, 3) Metric = 1074.7066110954088
# Max weight: 10000.0
# Noise: 70 Best permutation for layer2: (3, 4, 0, 2, 1, 5) Metric = 568.4056091754231
# Max weight: 10000.0
# Noise: 75 Best permutation for layer2: (2, 0, 3, 5, 4, 1) Metric = 886.8220215345335
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (3, 1, 5, 2, 0, 4) Metric = 932.1609776957914
# Max weight: 10000.0
# Noise: 85 Best permutation for layer2: (4, 3, 2, 5, 1, 0) Metric = 915.6536161537409
# Max weight: 10000.0
# Noise: 90 Best permutation for layer2: (3, 0, 2, 4, 1, 5) Metric = 1765.8809126257445
# Max weight: 10000.0
# Noise: 95 Best permutation for layer2: (4, 2, 5, 0, 1, 3) Metric = 1363.4100671588349
# Max weight: 7988.6413245880985
# Noise: 100 Best permutation for layer2: (1, 5, 3, 4, 0, 2) Metric = 1133.6819757971298
# Max weight: 10000.0
# Noise: 105 Best permutation for layer2: (2, 0, 3, 4, 5, 1) Metric = 1088.0664332379295
# Max weight: 7068.656484082599
# Noise: 110 Best permutation for layer2: (1, 5, 2, 3, 0, 4) Metric = 1724.9368842043996
# Max weight: 10000.0
# Noise: 115 Best permutation for layer2: (4, 1, 5, 0, 2, 3) Metric = 1037.0061298484975
# Max weight: 3480.8139168573393
# Noise: 120 Best permutation for layer2: (5, 1, 3, 0, 4, 2) Metric = 2035.8649711152088
# Max weight: 5416.824249138628
# Noise: 10 Best permutation for layer2: (0, 5, 1, 2, 3, 4) Metric = 180.54179595344536
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (3, 5, 4, 2, 1, 0) Metric = 317.50757166942424
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (2, 1, 3, 4, 5, 0) Metric = 169.14488658699844
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (3, 2, 0, 4, 1, 5) Metric = 400.2150200338747
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (2, 3, 5, 1, 4, 0) Metric = 284.2239943008972
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (2, 4, 5, 3, 1, 0) Metric = 123.0145622425723
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (2, 4, 3, 0, 1, 5) Metric = 131.8860539263045
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (1, 5, 4, 0, 2, 3) Metric = 190.57853752687254
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (4, 1, 3, 5, 0, 2) Metric = 715.0692760522422
# Max weight: 4503.680310960742
# Noise: 55 Best permutation for layer2: (5, 3, 0, 2, 4, 1) Metric = 348.37443587308104
# Max weight: 10000.0
# Noise: 60 Best permutation for layer2: (5, 1, 3, 0, 4, 2) Metric = 78.54659839397834
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (1, 5, 3, 2, 0, 4) Metric = 434.7795670920134
# Max weight: 10000.0
# Noise: 70 Best permutation for layer2: (5, 3, 1, 4, 0, 2) Metric = 150.405659409979
# Max weight: 2208.798104203069
# Noise: 75 Best permutation for layer2: (0, 1, 4, 5, 2, 3) Metric = 279.8741963230193
# Max weight: 6830.686148164919
# Noise: 80 Best permutation for layer2: (4, 0, 2, 5, 1, 3) Metric = 232.35323738571236
# Max weight: 1234.4996743830518
# Noise: 85 Best permutation for layer2: (3, 2, 4, 0, 1, 5) Metric = 276.36288705835545
# Max weight: 9459.54113745036
# Noise: 90 Best permutation for layer2: (4, 3, 0, 1, 5, 2) Metric = 126.82160870808914
# Max weight: 5986.446516906345
# Noise: 95 Best permutation for layer2: (0, 5, 1, 4, 2, 3) Metric = 362.4854464494808
# Max weight: 9692.920157083507
# Noise: 100 Best permutation for layer2: (3, 2, 4, 1, 5, 0) Metric = 112.07713941164513
# Max weight: 3590.528446251046
# Noise: 105 Best permutation for layer2: (5, 2, 0, 1, 4, 3) Metric = 172.67984764820665
# Max weight: 3339.82778029225
# Noise: 110 Best permutation for layer2: (0, 4, 3, 5, 2, 1) Metric = 421.1084904101143
# Max weight: 10000.0
# Noise: 115 Best permutation for layer2: (3, 0, 1, 5, 4, 2) Metric = 213.66328459333843
# Max weight: 8389.363311149604
# Noise: 120 Best permutation for layer2: (1, 0, 5, 2, 3, 4) Metric = 261.35256356525946
# Max weight: 9974.11378891229
# Noise: 10 Best permutation for layer2: (2, 4, 0, 3, 1, 5) Metric = 220.7420596723428
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (2, 1, 0, 3, 4, 5) Metric = 167.84790500356672
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (5, 0, 1, 4, 2, 3) Metric = 150.92693531098917
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (0, 3, 4, 1, 2, 5) Metric = 0.0
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (3, 1, 0, 5, 4, 2) Metric = 13.425748704890584
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (0, 4, 2, 3, 5, 1) Metric = 11.063904808385665
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (1, 3, 4, 0, 2, 5) Metric = 143.73084782320743
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (5, 4, 3, 2, 0, 1) Metric = 156.8312139349726
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (0, 2, 3, 1, 5, 4) Metric = 4.222147408124825
# Max weight: 5624.301421666573
# Noise: 55 Best permutation for layer2: (1, 5, 3, 0, 4, 2) Metric = 67.29062755562451
# Max weight: 3099.2396287155884
# Noise: 60 Best permutation for layer2: (3, 2, 4, 1, 0, 5) Metric = 12.0
# Max weight: 2241.5489733443032
# Noise: 65 Best permutation for layer2: (1, 3, 2, 5, 0, 4) Metric = 5.325712176169867
# Max weight: 750.3191179730496
# Noise: 70 Best permutation for layer2: (4, 2, 1, 3, 0, 5) Metric = 164.57370016610238
# Max weight: 1798.0747984525794
# Noise: 75 Best permutation for layer2: (1, 3, 2, 5, 0, 4) Metric = 40.01701228582496
# Max weight: 9119.921039308792
# Noise: 80 Best permutation for layer2: (1, 2, 3, 5, 0, 4) Metric = 65.00105252642263
# Max weight: 8452.724224889878
# Noise: 85 Best permutation for layer2: (1, 3, 2, 5, 4, 0) Metric = 12.963338007175645
# Max weight: 5297.179510254113
# Noise: 90 Best permutation for layer2: (0, 2, 1, 4, 3, 5) Metric = 20.980594744480953
# Max weight: 2636.458996038193
# Noise: 95 Best permutation for layer2: (0, 5, 1, 2, 3, 4) Metric = 8.1920590666187
# Max weight: 595.8872545116586
# Noise: 100 Best permutation for layer2: (0, 1, 4, 3, 2, 5) Metric = 0.0
# Max weight: 377.28844176712437
# Noise: 105 Best permutation for layer2: (3, 5, 4, 1, 2, 0) Metric = 0.0
# Max weight: 471.3381936824571
# Noise: 110 Best permutation for layer2: (3, 1, 0, 4, 2, 5) Metric = 4.895436407981899
# Max weight: 1854.205218215324
# Noise: 115 Best permutation for layer2: (3, 2, 1, 4, 0, 5) Metric = 20.522357851941194
# Max weight: 1082.3594980234384
# Noise: 120 Best permutation for layer2: (0, 2, 1, 3, 4, 5) Metric = 53.13600011223868
# Max weight: 10000.0
# Noise: 10 Best permutation for layer2: (0, 5, 4, 1, 2, 3) Metric = 0.0
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (0, 3, 2, 4, 1, 5) Metric = 0.0
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (0, 1, 2, 4, 3, 5) Metric = 0.0
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (0, 3, 1, 2, 4, 5) Metric = 0.0
# Max weight: 9710.637931937552
# Noise: 30 Best permutation for layer2: (0, 5, 4, 2, 3, 1) Metric = 128.36751159902911
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (3, 2, 4, 0, 1, 5) Metric = 137.4982122244963
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (1, 2, 0, 5, 4, 3) Metric = 302.533134585448
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (0, 2, 3, 4, 1, 5) Metric = 0.0
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (0, 3, 2, 4, 1, 5) Metric = 0.0
# Max weight: 599.5958038357836
# Noise: 55 Best permutation for layer2: (0, 1, 2, 4, 3, 5) Metric = 0.0
# Max weight: 938.0532011481457
# Noise: 60 Best permutation for layer2: (1, 2, 3, 4, 0, 5) Metric = 11.123083161040956
# Max weight: 1008.7773246826672
# Noise: 65 Best permutation for layer2: (0, 1, 5, 4, 2, 3) Metric = 30.817727134705134
# Max weight: 8417.213107478728
# Noise: 70 Best permutation for layer2: (0, 3, 1, 2, 4, 5) Metric = 0.0
# Max weight: 691.9122379293998
# Noise: 75 Best permutation for layer2: (0, 4, 1, 5, 3, 2) Metric = 0.0
# Max weight: 1395.0961442525327
# Noise: 80 Best permutation for layer2: (1, 5, 2, 0, 4, 3) Metric = 0.0
# Max weight: 264.12377601150274
# Noise: 85 Best permutation for layer2: (2, 0, 3, 4, 1, 5) Metric = 0.0
# Max weight: 136.65396515650133
# Noise: 90 Best permutation for layer2: (1, 2, 3, 4, 0, 5) Metric = 0.0
# Max weight: 24.80134517145548
# Noise: 95 Best permutation for layer2: (2, 1, 3, 4, 0, 5) Metric = 0.0
# Max weight: 59.44846336586675
# Noise: 100 Best permutation for layer2: (1, 0, 2, 4, 3, 5) Metric = 0.0
# Max weight: 39.545651741895206
# Noise: 105 Best permutation for layer2: (0, 1, 2, 4, 3, 5) Metric = 0.0
# Max weight: 8.02643264858374
# Noise: 110 Best permutation for layer2: (1, 3, 2, 4, 0, 5) Metric = 0.0
# Max weight: 19.79517852062152
# Noise: 115 Best permutation for layer2: (0, 5, 1, 2, 4, 3) Metric = 0.0
# Max weight: 8.03265106670598
# Noise: 120 Best permutation for layer2: (0, 5, 1, 2, 3, 4) Metric = 0.0
# Max weight: 127.89416399448376
# Noise: 10 Best permutation for layer2: (5, 0, 3, 2, 4, 1) Metric = 505.7352531195462
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (1, 2, 0, 3, 4, 5) Metric = 750.7806188963976
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (0, 3, 1, 5, 2, 4) Metric = 359.5893926477459
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (0, 5, 2, 1, 3, 4) Metric = 1093.268746707016
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (5, 3, 2, 0, 4, 1) Metric = 1119.0216953074394
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (4, 1, 3, 0, 5, 2) Metric = 477.61094661768686
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (1, 0, 3, 2, 5, 4) Metric = 1440.4619104370165
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (0, 4, 1, 2, 3, 5) Metric = 458.2696179034207
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (4, 0, 5, 1, 2, 3) Metric = 534.7116403422358
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (1, 3, 5, 4, 2, 0) Metric = 751.7109993271763
# Max weight: 10000.0
# Noise: 60 Best permutation for layer2: (3, 1, 2, 0, 4, 5) Metric = 1307.6473079886357
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (5, 1, 0, 2, 4, 3) Metric = 1684.0731750598934
# Max weight: 7675.727497981867
# Noise: 70 Best permutation for layer2: (0, 3, 2, 5, 1, 4) Metric = 1376.981327134098
# Max weight: 10000.0
# Noise: 75 Best permutation for layer2: (3, 0, 1, 4, 5, 2) Metric = 823.4470796614825
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (3, 5, 4, 1, 2, 0) Metric = 1366.1903824101782
# Max weight: 10000.0
# Noise: 85 Best permutation for layer2: (5, 3, 1, 0, 4, 2) Metric = 2158.4796447148287
# Max weight: 8635.681474799205
# Noise: 90 Best permutation for layer2: (2, 5, 0, 3, 4, 1) Metric = 1601.1439893834834
# Max weight: 10000.0
# Noise: 95 Best permutation for layer2: (5, 3, 2, 4, 0, 1) Metric = 1090.2156578604443
# Max weight: 10000.0
# Noise: 100 Best permutation for layer2: (5, 3, 0, 4, 2, 1) Metric = 2443.847155295022
# Max weight: 10000.0
# Noise: 105 Best permutation for layer2: (5, 0, 4, 2, 3, 1) Metric = 620.2848817258953
# Max weight: 10000.0
# Noise: 110 Best permutation for layer2: (0, 1, 4, 5, 2, 3) Metric = 2320.8831064675437
# Max weight: 10000.0
# Noise: 115 Best permutation for layer2: (5, 4, 2, 3, 1, 0) Metric = 1164.6404370393343
# Max weight: 5503.346896790244
# Noise: 120 Best permutation for layer2: (5, 3, 4, 2, 0, 1) Metric = 904.152408755665
# Max weight: 10000.0
# Noise: 10 Best permutation for layer2: (5, 1, 0, 3, 4, 2) Metric = 527.0959398059222
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (2, 1, 3, 4, 5, 0) Metric = 716.8732050870599
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (0, 3, 2, 1, 5, 4) Metric = 274.56184194511843
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (1, 4, 3, 2, 5, 0) Metric = 292.5763657962945
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (1, 4, 5, 0, 2, 3) Metric = 282.11137583004995
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (5, 1, 2, 4, 3, 0) Metric = 260.7395735610606
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (2, 1, 5, 3, 4, 0) Metric = 244.5806030844966
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (2, 5, 1, 0, 4, 3) Metric = 154.50712186727992
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (1, 5, 0, 3, 2, 4) Metric = 290.67125875308886
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (2, 3, 1, 5, 4, 0) Metric = 139.03768910220896
# Max weight: 10000.0
# Noise: 60 Best permutation for layer2: (0, 4, 5, 2, 3, 1) Metric = 116.31395569525905
# Max weight: 8414.203439161252
# Noise: 65 Best permutation for layer2: (0, 2, 3, 4, 5, 1) Metric = 266.34517941740927
# Max weight: 10000.0
# Noise: 70 Best permutation for layer2: (1, 5, 2, 3, 4, 0) Metric = 354.26867025288084
# Max weight: 10000.0
# Noise: 75 Best permutation for layer2: (1, 0, 4, 5, 3, 2) Metric = 358.64491739984305
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (0, 3, 5, 4, 1, 2) Metric = 378.2632614744147
# Max weight: 10000.0
# Noise: 85 Best permutation for layer2: (1, 0, 4, 5, 3, 2) Metric = 383.83736302234206
# Max weight: 9881.358505753838
# Noise: 90 Best permutation for layer2: (1, 0, 3, 4, 5, 2) Metric = 208.9032003179056
# Max weight: 3429.9705558389337
# Noise: 95 Best permutation for layer2: (0, 3, 2, 4, 1, 5) Metric = 99.60437292237893
# Max weight: 5817.896326182252
# Noise: 100 Best permutation for layer2: (2, 4, 3, 0, 5, 1) Metric = 365.86086665032394
# Max weight: 6057.5477869003025
# Noise: 105 Best permutation for layer2: (5, 4, 1, 2, 3, 0) Metric = 130.4681907868402
# Max weight: 7427.047665850235
# Noise: 110 Best permutation for layer2: (1, 4, 3, 5, 0, 2) Metric = 60.92647562331739
# Max weight: 10000.0
# Noise: 115 Best permutation for layer2: (4, 3, 1, 5, 0, 2) Metric = 226.83061399012192
# Max weight: 541.5388153390312
# Noise: 120 Best permutation for layer2: (5, 2, 0, 3, 4, 1) Metric = 441.41806135944785
# Max weight: 5505.98124115839
# Noise: 10 Best permutation for layer2: (2, 1, 4, 5, 0, 3) Metric = 179.54625317994493
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (2, 3, 0, 1, 5, 4) Metric = 307.5602646504693
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (0, 2, 3, 5, 1, 4) Metric = 276.59411892977613
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (3, 2, 1, 0, 5, 4) Metric = 182.73313727243612
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (0, 3, 1, 5, 4, 2) Metric = 112.59074577155634
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (1, 5, 3, 0, 4, 2) Metric = 123.11921687937422
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (3, 0, 4, 1, 2, 5) Metric = 329.66913726579105
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (2, 3, 4, 0, 1, 5) Metric = 165.07952098168755
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (0, 3, 2, 5, 4, 1) Metric = 167.10932072921022
# Max weight: 7857.584508038284
# Noise: 55 Best permutation for layer2: (0, 4, 5, 2, 1, 3) Metric = 174.38588336509213
# Max weight: 6871.420157013117
# Noise: 60 Best permutation for layer2: (1, 0, 2, 3, 4, 5) Metric = 208.80327545965866
# Max weight: 2865.097162138023
# Noise: 65 Best permutation for layer2: (1, 3, 4, 0, 5, 2) Metric = 60.53386041130268
# Max weight: 8097.621901031688
# Noise: 70 Best permutation for layer2: (3, 4, 1, 5, 2, 0) Metric = 76.30847223479374
# Max weight: 5778.940878185615
# Noise: 75 Best permutation for layer2: (1, 0, 3, 4, 2, 5) Metric = 42.97821321419218
# Max weight: 860.5961649766546
# Noise: 80 Best permutation for layer2: (1, 3, 5, 4, 0, 2) Metric = 58.80218418448889
# Max weight: 8739.22363585443
# Noise: 85 Best permutation for layer2: (1, 3, 0, 2, 4, 5) Metric = 0.0
# Max weight: 2582.8327641610335
# Noise: 90 Best permutation for layer2: (0, 3, 2, 5, 4, 1) Metric = 38.42785695531077
# Max weight: 8070.5494108370685
# Noise: 95 Best permutation for layer2: (2, 0, 4, 3, 5, 1) Metric = 88.76301966332625
# Max weight: 190.17069348707693
# Noise: 100 Best permutation for layer2: (3, 2, 1, 4, 0, 5) Metric = 8.766169591874377
# Max weight: 44.78566406995825
# Noise: 105 Best permutation for layer2: (0, 4, 5, 3, 1, 2) Metric = 112.64540448810139
# Max weight: 1726.8857599749404
# Noise: 110 Best permutation for layer2: (0, 1, 5, 4, 2, 3) Metric = 162.24461980842364
# Max weight: 2793.324182991865
# Noise: 115 Best permutation for layer2: (1, 2, 3, 4, 5, 0) Metric = 6.835860188213996
# Max weight: 7250.306712716586
# Noise: 120 Best permutation for layer2: (2, 5, 1, 0, 4, 3) Metric = 120.22115031462404
# Max weight: 860.1630528840307
# Noise: 10 Best permutation for layer2: (0, 2, 4, 1, 3, 5) Metric = 96.0
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (0, 4, 2, 1, 5, 3) Metric = 171.34944590789087
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (0, 3, 4, 1, 2, 5) Metric = 125.85876396396492
# Max weight: 9677.352502217158
# Noise: 25 Best permutation for layer2: (0, 1, 2, 3, 5, 4) Metric = 163.64957750037092
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (5, 0, 3, 4, 2, 1) Metric = 112.14752832157265
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (1, 2, 4, 0, 5, 3) Metric = 80.63766783083739
# Max weight: 2914.270822123632
# Noise: 40 Best permutation for layer2: (4, 2, 0, 5, 1, 3) Metric = 84.53714062979232
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (5, 0, 1, 2, 3, 4) Metric = 22.691865355410563
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (4, 0, 3, 2, 5, 1) Metric = 0.0
# Max weight: 9586.162635261075
# Noise: 55 Best permutation for layer2: (4, 0, 1, 3, 2, 5) Metric = 18.660917672578073
# Max weight: 3381.727432773979
# Noise: 60 Best permutation for layer2: (0, 1, 2, 3, 4, 5) Metric = 83.15464904370435
# Max weight: 1617.4072862036776
# Noise: 65 Best permutation for layer2: (1, 3, 0, 4, 5, 2) Metric = 16.241933770099646
# Max weight: 2009.4472980014089
# Noise: 70 Best permutation for layer2: (1, 0, 2, 5, 3, 4) Metric = 0.0
# Max weight: 3393.912902198623
# Noise: 75 Best permutation for layer2: (5, 1, 2, 3, 4, 0) Metric = 0.0
# Max weight: 274.62476343222255
# Noise: 80 Best permutation for layer2: (1, 0, 2, 4, 3, 5) Metric = 0.0
# Max weight: 86.61904272956521
# Noise: 85 Best permutation for layer2: (0, 1, 3, 4, 2, 5) Metric = 21.620389428776516
# Max weight: 707.7450389266398
# Noise: 90 Best permutation for layer2: (5, 0, 4, 2, 3, 1) Metric = 37.523367836733975
# Max weight: 28.743222613462784
# Noise: 95 Best permutation for layer2: (3, 0, 1, 2, 4, 5) Metric = 19.020274735020525
# Max weight: 316.18351702164045
# Noise: 100 Best permutation for layer2: (4, 0, 1, 2, 3, 5) Metric = 0.0
# Max weight: 193.73246578473882
# Noise: 105 Best permutation for layer2: (1, 0, 2, 3, 4, 5) Metric = 0.0
# Max weight: 12.856757705490605
# Noise: 110 Best permutation for layer2: (3, 0, 1, 2, 4, 5) Metric = 0.0
# Max weight: 275.95151401905554
# Noise: 115 Best permutation for layer2: (4, 0, 1, 3, 2, 5) Metric = 0.0
# Max weight: 7.238019126811315
# Noise: 120 Best permutation for layer2: (2, 0, 1, 3, 4, 5) Metric = 0.0
# Max weight: 67.54634376860979
# Noise: 10 Best permutation for layer2: (4, 5, 2, 0, 3, 1) Metric = 1146.2808366910115
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (4, 1, 3, 0, 5, 2) Metric = 646.69112109158
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (5, 0, 3, 1, 2, 4) Metric = 659.5074888844463
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (0, 3, 1, 5, 2, 4) Metric = 739.609854866106
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (1, 3, 4, 0, 5, 2) Metric = 876.5532967901348
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (0, 1, 3, 5, 4, 2) Metric = 575.1340701500045
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (1, 4, 3, 2, 5, 0) Metric = 1207.4364509536422
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (0, 1, 4, 2, 5, 3) Metric = 622.7904018530893
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (0, 2, 1, 3, 5, 4) Metric = 701.6064744930247
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (0, 4, 2, 3, 1, 5) Metric = 727.9439004365693
# Max weight: 10000.0
# Noise: 60 Best permutation for layer2: (0, 4, 3, 1, 2, 5) Metric = 2085.019349568253
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (1, 0, 4, 5, 3, 2) Metric = 1123.2484567367553
# Max weight: 10000.0
# Noise: 70 Best permutation for layer2: (3, 4, 5, 2, 1, 0) Metric = 1003.813490463521
# Max weight: 10000.0
# Noise: 75 Best permutation for layer2: (0, 2, 1, 3, 4, 5) Metric = 1210.300318541673
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (2, 1, 4, 5, 3, 0) Metric = 1774.8197215386213
# Max weight: 8954.02020582339
# Noise: 85 Best permutation for layer2: (0, 3, 4, 5, 2, 1) Metric = 612.7149918506366
# Max weight: 10000.0
# Noise: 90 Best permutation for layer2: (2, 3, 0, 4, 1, 5) Metric = 463.6949085879472
# Max weight: 10000.0
# Noise: 95 Best permutation for layer2: (3, 4, 2, 1, 0, 5) Metric = 1128.413576578691
# Max weight: 10000.0
# Noise: 100 Best permutation for layer2: (3, 5, 0, 2, 4, 1) Metric = 1476.912577277672
# Max weight: 10000.0
# Noise: 105 Best permutation for layer2: (0, 4, 1, 3, 2, 5) Metric = 1147.1535109188974
# Max weight: 9995.93005574799
# Noise: 110 Best permutation for layer2: (0, 1, 4, 3, 2, 5) Metric = 896.9211574840804
# Max weight: 10000.0
# Noise: 115 Best permutation for layer2: (4, 0, 1, 2, 3, 5) Metric = 1265.4942998495771
# Max weight: 10000.0
# Noise: 120 Best permutation for layer2: (3, 0, 2, 4, 5, 1) Metric = 1184.6920044966662
# Max weight: 10000.0
# Noise: 10 Best permutation for layer2: (3, 0, 1, 4, 5, 2) Metric = 269.6041722001717
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (5, 2, 0, 4, 1, 3) Metric = 428.80171668468006
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (0, 2, 1, 4, 5, 3) Metric = 615.039815505747
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (0, 5, 1, 2, 3, 4) Metric = 269.12045246937964
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (2, 0, 5, 4, 3, 1) Metric = 281.4668727069149
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (0, 1, 3, 5, 2, 4) Metric = 107.65628076131395
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (1, 5, 2, 3, 4, 0) Metric = 392.378018832076
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (5, 1, 2, 4, 0, 3) Metric = 650.865956944161
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (4, 0, 2, 1, 5, 3) Metric = 442.5587800054184
# Max weight: 8325.854670842295
# Noise: 55 Best permutation for layer2: (5, 3, 4, 1, 2, 0) Metric = 441.6453240078765
# Max weight: 10000.0
# Noise: 60 Best permutation for layer2: (4, 2, 0, 1, 3, 5) Metric = 384.1958794309803
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (3, 5, 4, 0, 2, 1) Metric = 397.60278747777966
# Max weight: 10000.0
# Noise: 70 Best permutation for layer2: (2, 3, 0, 5, 1, 4) Metric = 615.560319763544
# Max weight: 10000.0
# Noise: 75 Best permutation for layer2: (1, 5, 4, 2, 0, 3) Metric = 651.9642995676332
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (2, 5, 1, 4, 3, 0) Metric = 179.9538820648778
# Max weight: 10000.0
# Noise: 85 Best permutation for layer2: (3, 0, 1, 5, 2, 4) Metric = 711.7469531530736
# Max weight: 9818.176010631345
# Noise: 90 Best permutation for layer2: (5, 4, 2, 3, 1, 0) Metric = 358.61016283923686
# Max weight: 10000.0
# Noise: 95 Best permutation for layer2: (2, 5, 4, 0, 3, 1) Metric = 90.34866499376069
# Max weight: 10000.0
# Noise: 100 Best permutation for layer2: (1, 4, 3, 5, 0, 2) Metric = 318.8472154410015
# Max weight: 1940.8693114408493
# Noise: 105 Best permutation for layer2: (5, 2, 1, 0, 4, 3) Metric = 285.70580767955107
# Max weight: 10000.0
# Noise: 110 Best permutation for layer2: (5, 3, 0, 2, 4, 1) Metric = 445.7882903989831
# Max weight: 10000.0
# Noise: 115 Best permutation for layer2: (0, 1, 2, 5, 4, 3) Metric = 574.5035031499524
# Max weight: 7610.643963406926
# Noise: 120 Best permutation for layer2: (4, 0, 3, 2, 1, 5) Metric = 501.13050598310593
# Max weight: 5758.786242524415
# Noise: 10 Best permutation for layer2: (2, 3, 0, 1, 4, 5) Metric = 268.6251993055868
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (5, 1, 0, 4, 2, 3) Metric = 155.94865830188002
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (0, 3, 2, 4, 1, 5) Metric = 149.78057937329822
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (1, 0, 2, 3, 5, 4) Metric = 171.84661334251933
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (1, 4, 5, 2, 3, 0) Metric = 392.2661076762099
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (2, 0, 4, 3, 5, 1) Metric = 321.341767782291
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (2, 4, 0, 1, 3, 5) Metric = 140.00075368699535
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (3, 0, 4, 1, 2, 5) Metric = 129.672288743599
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (5, 4, 0, 3, 1, 2) Metric = 70.0955652553311
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (3, 0, 4, 2, 1, 5) Metric = 334.83544365664835
# Max weight: 10000.0
# Noise: 60 Best permutation for layer2: (4, 2, 0, 1, 3, 5) Metric = 298.8062928355704
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (2, 3, 5, 1, 4, 0) Metric = 327.21642362529934
# Max weight: 6345.281898861162
# Noise: 70 Best permutation for layer2: (2, 1, 3, 0, 4, 5) Metric = 321.1629165115256
# Max weight: 4178.627935370133
# Noise: 75 Best permutation for layer2: (0, 1, 2, 3, 4, 5) Metric = 0.0
# Max weight: 7974.451967089717
# Noise: 80 Best permutation for layer2: (1, 5, 2, 0, 4, 3) Metric = 287.69831262463623
# Max weight: 10000.0
# Noise: 85 Best permutation for layer2: (4, 5, 0, 1, 2, 3) Metric = 259.5093180728687
# Max weight: 7872.83660461152
# Noise: 90 Best permutation for layer2: (0, 5, 4, 2, 1, 3) Metric = 332.4927476841316
# Max weight: 2211.2973560134105
# Noise: 95 Best permutation for layer2: (3, 2, 5, 1, 4, 0) Metric = 157.91441210561226
# Max weight: 4332.058140145401
# Noise: 100 Best permutation for layer2: (4, 5, 2, 3, 0, 1) Metric = 281.6247048515553
# Max weight: 7072.717837544971
# Noise: 105 Best permutation for layer2: (3, 0, 5, 2, 1, 4) Metric = 4.135210790194419
# Max weight: 2516.0388162748063
# Noise: 110 Best permutation for layer2: (2, 1, 0, 3, 5, 4) Metric = 52.07416269027751
# Max weight: 10000.0
# Noise: 115 Best permutation for layer2: (3, 4, 1, 0, 2, 5) Metric = 222.0995496466818
# Max weight: 5489.786324940273
# Noise: 120 Best permutation for layer2: (0, 1, 4, 5, 2, 3) Metric = 129.41789769887703
# Max weight: 781.5196465375813
# Noise: 10 Best permutation for layer2: (3, 2, 0, 5, 4, 1) Metric = 0.0
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (1, 2, 0, 4, 5, 3) Metric = 193.06085027244484
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (1, 0, 2, 3, 4, 5) Metric = 0.0
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (3, 0, 1, 4, 2, 5) Metric = 141.02336633577403
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (1, 2, 4, 3, 5, 0) Metric = 87.22428173772076
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (3, 0, 1, 2, 4, 5) Metric = 0.0
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (0, 1, 2, 3, 5, 4) Metric = 156.0
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (4, 0, 1, 3, 2, 5) Metric = 154.52786680866316
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (3, 5, 0, 4, 1, 2) Metric = 160.54261268980872
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (1, 2, 4, 3, 0, 5) Metric = 200.7450268757308
# Max weight: 8138.871346317607
# Noise: 60 Best permutation for layer2: (2, 0, 1, 3, 4, 5) Metric = 0.0
# Max weight: 9180.462976927938
# Noise: 65 Best permutation for layer2: (5, 0, 1, 2, 3, 4) Metric = 9.238815673692011
# Max weight: 8968.129753454905
# Noise: 70 Best permutation for layer2: (0, 4, 1, 2, 3, 5) Metric = 70.79414200619496
# Max weight: 10000.0
# Noise: 75 Best permutation for layer2: (0, 4, 2, 3, 5, 1) Metric = 59.91294489957971
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (5, 0, 2, 1, 4, 3) Metric = 0.0
# Max weight: 10000.0
# Noise: 85 Best permutation for layer2: (0, 4, 5, 2, 3, 1) Metric = 44.17182391668854
# Max weight: 6711.245855649062
# Noise: 90 Best permutation for layer2: (3, 0, 1, 4, 5, 2) Metric = 0.0
# Max weight: 4919.487063495774
# Noise: 95 Best permutation for layer2: (1, 2, 0, 3, 4, 5) Metric = 103.9528511320555
# Max weight: 96.83661437710467
# Noise: 100 Best permutation for layer2: (0, 4, 1, 2, 3, 5) Metric = 150.46363105085575
# Max weight: 32.795682895408895
# Noise: 105 Best permutation for layer2: (4, 0, 1, 2, 3, 5) Metric = 0.0
# Max weight: 429.535418295417
# Noise: 110 Best permutation for layer2: (0, 2, 1, 4, 3, 5) Metric = 65.84375768811879
# Max weight: 72.93684366064561
# Noise: 115 Best permutation for layer2: (2, 0, 1, 3, 4, 5) Metric = 0.0
# Max weight: 472.6965648479644
# Noise: 120 Best permutation for layer2: (1, 2, 3, 0, 4, 5) Metric = 126.06859648059773
# Max weight: 11.866738051610433
# Noise: 10 Best permutation for layer2: (4, 2, 1, 3, 5, 0) Metric = 579.982268368467
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (5, 3, 1, 0, 2, 4) Metric = 451.85376312830175
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (2, 4, 3, 5, 1, 0) Metric = 978.3097689176344
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (2, 0, 3, 4, 1, 5) Metric = 558.1225555544584
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (2, 4, 0, 5, 3, 1) Metric = 938.0020527933561
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (5, 0, 3, 2, 1, 4) Metric = 890.2793791733093
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (5, 2, 4, 0, 3, 1) Metric = 937.812870474842
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (4, 5, 2, 3, 1, 0) Metric = 718.5981686167977
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (4, 3, 1, 5, 0, 2) Metric = 1003.0927890359993
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (0, 2, 4, 5, 1, 3) Metric = 428.5446911678944
# Max weight: 9527.049673340458
# Noise: 60 Best permutation for layer2: (3, 1, 2, 5, 4, 0) Metric = 1878.4182505354327
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (5, 1, 2, 3, 0, 4) Metric = 705.4827985608822
# Max weight: 10000.0
# Noise: 70 Best permutation for layer2: (0, 5, 1, 2, 3, 4) Metric = 668.9435803258442
# Max weight: 10000.0
# Noise: 75 Best permutation for layer2: (2, 0, 4, 5, 1, 3) Metric = 1423.2337206881664
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (3, 4, 2, 0, 1, 5) Metric = 1749.4804600405223
# Max weight: 9596.357157310214
# Noise: 85 Best permutation for layer2: (1, 5, 0, 2, 4, 3) Metric = 1256.6919033866868
# Max weight: 10000.0
# Noise: 90 Best permutation for layer2: (4, 0, 5, 3, 2, 1) Metric = 1602.1916833201135
# Max weight: 10000.0
# Noise: 95 Best permutation for layer2: (1, 4, 5, 3, 0, 2) Metric = 1304.8985180303284
# Max weight: 10000.0
# Noise: 100 Best permutation for layer2: (5, 1, 2, 3, 0, 4) Metric = 1037.8769159426047
# Max weight: 10000.0
# Noise: 105 Best permutation for layer2: (3, 5, 0, 1, 4, 2) Metric = 820.829796719308
# Max weight: 10000.0
# Noise: 110 Best permutation for layer2: (5, 4, 2, 0, 1, 3) Metric = 924.8644544866652
# Max weight: 10000.0
# Noise: 115 Best permutation for layer2: (5, 3, 4, 2, 0, 1) Metric = 1554.5607995616906
# Max weight: 10000.0
# Noise: 120 Best permutation for layer2: (1, 4, 0, 2, 3, 5) Metric = 2075.53960290591
# Max weight: 9121.970202823119
# Noise: 10 Best permutation for layer2: (2, 3, 1, 4, 0, 5) Metric = 225.12302107932956
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (4, 1, 2, 3, 5, 0) Metric = 408.69550913417305
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (0, 4, 2, 3, 5, 1) Metric = 302.69176589815305
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (2, 4, 3, 5, 0, 1) Metric = 1116.310919928335
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (1, 3, 2, 0, 4, 5) Metric = 309.90426370914327
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (4, 0, 3, 5, 1, 2) Metric = 204.8387461373456
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (0, 3, 4, 2, 5, 1) Metric = 208.8076681217308
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (1, 0, 2, 5, 4, 3) Metric = 877.8119701277546
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (3, 5, 2, 1, 0, 4) Metric = 403.5510537207789
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (4, 1, 0, 2, 5, 3) Metric = 467.9224974043652
# Max weight: 10000.0
# Noise: 60 Best permutation for layer2: (5, 4, 2, 3, 0, 1) Metric = 578.0175016446227
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (4, 1, 2, 3, 0, 5) Metric = 621.4970360612144
# Max weight: 10000.0
# Noise: 70 Best permutation for layer2: (3, 0, 2, 4, 1, 5) Metric = 748.6088596210792
# Max weight: 10000.0
# Noise: 75 Best permutation for layer2: (0, 4, 2, 5, 1, 3) Metric = 745.3800691639082
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (3, 1, 4, 2, 5, 0) Metric = 479.02093099445244
# Max weight: 10000.0
# Noise: 85 Best permutation for layer2: (1, 3, 4, 0, 2, 5) Metric = 348.05923383438073
# Max weight: 5100.073115482224
# Noise: 90 Best permutation for layer2: (1, 4, 0, 2, 5, 3) Metric = 402.6241755898052
# Max weight: 10000.0
# Noise: 95 Best permutation for layer2: (1, 2, 0, 3, 5, 4) Metric = 421.1052204397004
# Max weight: 10000.0
# Noise: 100 Best permutation for layer2: (5, 0, 1, 2, 3, 4) Metric = 451.30449886669334
# Max weight: 5646.478823047807
# Noise: 105 Best permutation for layer2: (4, 1, 0, 5, 2, 3) Metric = 440.89728456974905
# Max weight: 10000.0
# Noise: 110 Best permutation for layer2: (5, 2, 0, 3, 4, 1) Metric = 623.8471526049145
# Max weight: 9001.949772585012
# Noise: 115 Best permutation for layer2: (1, 5, 0, 4, 3, 2) Metric = 623.3889714396378
# Max weight: 3325.204934596976
# Noise: 120 Best permutation for layer2: (2, 1, 0, 3, 4, 5) Metric = 575.363107400423
# Max weight: 10000.0
# Noise: 10 Best permutation for layer2: (1, 2, 0, 3, 4, 5) Metric = 319.4244551023081
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (5, 1, 3, 0, 4, 2) Metric = 27.37299270416328
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (0, 5, 2, 3, 1, 4) Metric = 123.84464144663698
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (2, 1, 5, 0, 3, 4) Metric = 236.88945420021304
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (3, 4, 1, 0, 2, 5) Metric = 116.60907833283812
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (5, 1, 2, 0, 3, 4) Metric = 221.66976099231798
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (1, 2, 0, 5, 3, 4) Metric = 105.93742065492913
# Max weight: 7116.027834857519
# Noise: 45 Best permutation for layer2: (0, 2, 1, 4, 3, 5) Metric = 87.07021316885692
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (0, 4, 2, 5, 1, 3) Metric = 128.65618158880687
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (4, 2, 3, 1, 0, 5) Metric = 371.6281863150907
# Max weight: 10000.0
# Noise: 60 Best permutation for layer2: (5, 3, 0, 4, 2, 1) Metric = 14.126194256146809
# Max weight: 3550.3446340007267
# Noise: 65 Best permutation for layer2: (3, 0, 2, 1, 5, 4) Metric = 185.32885667000144
# Max weight: 10000.0
# Noise: 70 Best permutation for layer2: (5, 3, 4, 1, 0, 2) Metric = 144.00953638661687
# Max weight: 10000.0
# Noise: 75 Best permutation for layer2: (5, 1, 3, 0, 2, 4) Metric = 29.60051579791816
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (5, 2, 4, 1, 0, 3) Metric = 262.91048391848597
# Max weight: 6355.954064377864
# Noise: 85 Best permutation for layer2: (4, 1, 2, 0, 3, 5) Metric = 119.14215136626689
# Max weight: 8765.264233708414
# Noise: 90 Best permutation for layer2: (5, 4, 1, 0, 3, 2) Metric = 639.5406213697279
# Max weight: 8732.019669055022
# Noise: 95 Best permutation for layer2: (1, 0, 4, 5, 3, 2) Metric = 99.2763920067568
# Max weight: 599.6507812488416
# Noise: 100 Best permutation for layer2: (2, 0, 4, 5, 1, 3) Metric = 110.15345130793624
# Max weight: 10000.0
# Noise: 105 Best permutation for layer2: (0, 3, 2, 5, 1, 4) Metric = 226.74677724122358
# Max weight: 9052.909861304894
# Noise: 110 Best permutation for layer2: (3, 5, 2, 4, 1, 0) Metric = 193.35469226438633
# Max weight: 10000.0
# Noise: 115 Best permutation for layer2: (1, 3, 4, 2, 5, 0) Metric = 421.7180243826944
# Max weight: 1400.978073830369
# Noise: 120 Best permutation for layer2: (1, 0, 2, 4, 3, 5) Metric = 193.80211867374388
# Max weight: 3611.638606918309
# Noise: 10 Best permutation for layer2: (3, 0, 1, 2, 4, 5) Metric = 0.0
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (0, 4, 3, 1, 2, 5) Metric = 11.487610041623888
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (0, 4, 3, 1, 2, 5) Metric = 169.18431318913215
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (3, 5, 4, 2, 0, 1) Metric = 203.2499973993938
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (3, 1, 0, 4, 2, 5) Metric = 0.0
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (2, 5, 3, 0, 1, 4) Metric = 111.17044336752606
# Max weight: 9441.168311740505
# Noise: 40 Best permutation for layer2: (4, 5, 1, 0, 2, 3) Metric = 104.27560264877823
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (4, 1, 5, 0, 2, 3) Metric = 32.43767196427441
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (3, 0, 2, 1, 4, 5) Metric = 0.0
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (1, 0, 4, 3, 2, 5) Metric = 88.75570797942504
# Max weight: 8384.377326479862
# Noise: 60 Best permutation for layer2: (4, 2, 5, 0, 1, 3) Metric = 0.0
# Max weight: 3927.339548322616
# Noise: 65 Best permutation for layer2: (1, 2, 4, 0, 3, 5) Metric = 0.0
# Max weight: 10000.0
# Noise: 70 Best permutation for layer2: (1, 0, 2, 4, 5, 3) Metric = 343.1704346354944
# Max weight: 8914.762073180713
# Noise: 75 Best permutation for layer2: (0, 4, 3, 1, 2, 5) Metric = 120.0
# Max weight: 1326.2086333847178
# Noise: 80 Best permutation for layer2: (1, 0, 3, 2, 4, 5) Metric = 19.580508018964082
# Max weight: 1837.2378701270668
# Noise: 85 Best permutation for layer2: (2, 3, 0, 1, 4, 5) Metric = 120.0
# Max weight: 4705.791772925814
# Noise: 90 Best permutation for layer2: (4, 1, 5, 2, 0, 3) Metric = 120.87369137096331
# Max weight: 10000.0
# Noise: 95 Best permutation for layer2: (2, 1, 3, 0, 4, 5) Metric = 10.229352421874232
# Max weight: 2525.075381894816
# Noise: 100 Best permutation for layer2: (3, 0, 2, 1, 4, 5) Metric = 95.55755400942049
# Max weight: 3174.40180720088
# Noise: 105 Best permutation for layer2: (1, 4, 2, 0, 3, 5) Metric = 0.0
# Max weight: 13.055588698199507
# Noise: 110 Best permutation for layer2: (1, 0, 4, 2, 3, 5) Metric = 0.0
# Max weight: 25.73339096810429
# Noise: 115 Best permutation for layer2: (4, 0, 1, 2, 3, 5) Metric = 19.244558682950156
# Max weight: 187.66323748145177
# Noise: 120 Best permutation for layer2: (0, 1, 2, 3, 4, 5) Metric = 0.0
# Max weight: 59.63510286337679
# Noise: 10 Best permutation for layer2: (0, 5, 4, 3, 2, 1) Metric = 486.81769655804055
# Max weight: 10000.0
# Noise: 15 Best permutation for layer2: (5, 4, 0, 1, 3, 2) Metric = 1362.9426324549968
# Max weight: 10000.0
# Noise: 20 Best permutation for layer2: (3, 4, 1, 0, 2, 5) Metric = 920.096268822937
# Max weight: 10000.0
# Noise: 25 Best permutation for layer2: (5, 2, 0, 4, 3, 1) Metric = 743.8274091955946
# Max weight: 10000.0
# Noise: 30 Best permutation for layer2: (5, 2, 1, 3, 4, 0) Metric = 531.7684025306452
# Max weight: 10000.0
# Noise: 35 Best permutation for layer2: (1, 0, 2, 5, 3, 4) Metric = 798.956914396397
# Max weight: 10000.0
# Noise: 40 Best permutation for layer2: (5, 4, 1, 2, 3, 0) Metric = 703.0564637364804
# Max weight: 10000.0
# Noise: 45 Best permutation for layer2: (3, 2, 4, 0, 5, 1) Metric = 1218.3533255391296
# Max weight: 10000.0
# Noise: 50 Best permutation for layer2: (1, 0, 3, 5, 4, 2) Metric = 605.4523658275798
# Max weight: 10000.0
# Noise: 55 Best permutation for layer2: (0, 3, 5, 4, 1, 2) Metric = 1147.2854408446156
# Max weight: 10000.0
# Noise: 60 Best permutation for layer2: (0, 3, 4, 2, 1, 5) Metric = 879.3290040150847
# Max weight: 10000.0
# Noise: 65 Best permutation for layer2: (5, 4, 3, 1, 2, 0) Metric = 1276.9182851787632
# Max weight: 10000.0
# Noise: 70 Best permutation for layer2: (5, 2, 4, 1, 3, 0) Metric = 984.225093630145
# Max weight: 10000.0
# Noise: 75 Best permutation for layer2: (4, 1, 2, 0, 3, 5) Metric = 2253.545748449822
# Max weight: 10000.0
# Noise: 80 Best permutation for layer2: (0, 1, 3, 4, 5, 2) Metric = 918.7169868734514
# Max weight: 10000.0
# Noise: 85 Best permutation for layer2: (4, 2, 5, 3, 0, 1) Metric = 1549.6309456299439
# Max weight: 10000.0
# Noise: 90 Best permutation for layer2: (0, 2, 1, 3, 5, 4) Metric = 1874.6798828403319
# Max weight: 10000.0
# Noise: 95 Best permutation for layer2: (3, 5, 0, 2, 1, 4) Metric = 2582.5827211766264
# Max weight: 10000.0
# Noise: 100 Best permutation for layer2: (1, 4, 2, 0, 3, 5) Metric = 1980.130628171921
# Max weight: 10000.0
# Noise: 105 Best permutation for layer2: (3, 4, 0, 1, 2, 5) Metric = 966.7491421992494
# Max weight: 10000.0
# Noise: 110 Best permutation for layer2: (4, 1, 3, 2, 0, 5) Metric = 1182.0194787199748
# Max weight: 9046.295264804998
# Noise: 115 Best permutation for layer2: (0, 4, 3, 5, 2, 1) Metric = 750.9228594850756
# Max weight: 5525.973008937137
# Noise: 120 Best permutation for layer2: (3, 0, 4, 5, 2, 1) Metric = 1304.9616396216047
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 159
#     157 # Save and display the SVG.
#     158 filename_svg = f"ChemClassifierWeb/images/CDN_{ID}.svg"
# --> 159 with open(filename_svg, "w") as f:
#     160      f.write(svg_output)
#     161 # display(SVG(svg_output))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# File <frozen codecs>:189, in __init__(self, errors)
#
# KeyboardInterrupt:
